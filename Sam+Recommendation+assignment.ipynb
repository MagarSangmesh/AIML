# %% [markdown]
# # • DOMAIN: Smartphone, Electronics
#
# # • CONTEXT:
# ###                          India is the second largest market globally for smartphones after China. About 134 million smartphones were sold across India in the year 2017 and is estimated to increase to about 442 million in 2022. India ranked second in the average time spent on mobile web by smartphone users across Asia Pacific. The combination of very high sales volumes and the average smartphone consumer behaviour has made India a very attractive market for foreign vendors. As per Consumer behaviour, 97% of consumers turn to a search engine when they are buying a product vs. 15% who turn to social media. If a seller succeeds to publish smartphones based on user’s behaviour/choice at the right place, there are 90% chances that user will enquire for the same. This Case Study is targeted to build a recommendation system based on individual consumer’s behaviour or choice.
# # • DATA DESCRIPTION:
# ###            • author : name of the person who gave the rating
# ###            • country : country the person who gave the rating belongs to
# ###            • data : date of the rating
# ###            • domain: website from which the rating was taken from
# ###            • extract: rating content
# ###            • language: language in which the rating was given
# ###            • product: name of the product/mobile phone for which the rating was given
# ###            • score: average rating for the phone
# ###            • score_max: highest rating given for the phone
# ###            • source: source from where the rating was taken
#
# # • PROJECT OBJECTIVE:
# ### We will build a recommendation system using popularity based and collaborative filtering methods to recommend mobile phones to a user which are most popular and personalised respectively.
#
# # Steps and tasks: [ Total Score: 60 points]
#
# ## 1. Import the necessary libraries and read the provided CSVs as a data frame and perform the below steps. [15 Marks]
#
#
# ### A. Merge all the provided CSVs into one dataFrame. [2 Marks]

# %%
import pandas as pd

dataframes = []
for i in range(1, 7):
    dataframes.append(pd.read_csv("./recommendation_systems/project/phone_user_review_file_" + str(i) + ".csv", encoding_errors = "ignore"))
    print(dataframes[i - 1].shape)
# Out:
# (374910, 11)
# (114925, 11)
# (312961, 11)
# (98284, 11)
# (350216, 11)
# (163837, 11)

# %%
dataset=pd.concat(dataframes)

# %%
dataset.shape
# Out:
# (1415133, 11)

# %% [markdown]
# ### B. Explore, understand the Data and share at least 2 observations. [2 Marks]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1415133 entries, 0 to 163836
# Data columns (total 11 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   phone_url  1415133 non-null  object
#  1   date       1415133 non-null  object
#  2   lang       1415133 non-null  object
#  3   country    1415133 non-null  object
#  4   source     1415133 non-null  object
#  5   domain     1415133 non-null  object
#  6   score      1351644 non-null  float64
#  7   score_max  1351644 non-null  float64
#  8   extract    1395772 non-null  object
#  9   author     1351931 non-null  object
#  10  product    1415132 non-null  object
# dtypes: float64(2), object(9)
# memory usage: 129.6+ MB

# %% [markdown]
# There are some null values in the dataset attributes **score, score_max, extract, author, product**

# %%
dataset.nunique()
# Out:
# phone_url       5556
# date            7728
# lang              22
# country           42
# source           331
# domain           384
# score             86
# score_max          1
# extract      1321342
# author        800288
# product        61313
# dtype: int64

# %% [markdown]
# #### • This data contains reviews of 5556 unique phones(The product attribute also differentiates between different configurations of               the same phone)
# #### • Data contains reviews written in 22 different languages(!)
# #### • Data was aggregated from 331 different sources

# %%
dataset["date"].sort_values()
# Out:
# 72391     1/1/1970
# 155613    1/1/2000
# 153187    1/1/2000
# 150864    1/1/2000
# 247876    1/1/2000
#             ...
# 17642     9/9/2016
# 292390    9/9/2016
# 292389    9/9/2016
# 292387    9/9/2016
# 251679    9/9/2016
# Name: date, Length: 1415133, dtype: object

# %%
dataset["date"] = pd.to_datetime(dataset["date"], infer_datetime_format = True)

# %%
dataset["date"].describe(datetime_is_numeric = True)
# Out:
# count                          1415133
# mean     2013-07-13 06:49:34.002302208
# min                1970-01-01 00:00:00
# 25%                2012-01-12 00:00:00
# 50%                2014-04-23 00:00:00
# 75%                2015-10-24 00:00:00
# max                2017-12-05 00:00:00
# Name: date, dtype: object

# %% [markdown]
# #### 25% of the reviews are from before 2012...

# %%
dataset["score"].value_counts()
# Out:
# 10.0    656239
# 8.0     296018
# 2.0     128485
# 6.0     116616
# 4.0      72462
#          ...
# 0.4          2
# 6.1          1
# 1.5          1
# 8.9          1
# 4.9          1
# Name: score, Length: 86, dtype: int64

# %% [markdown]
# #### Most of the reviews have a score of 10... Either the phones are very good, or the standards for providing a 10 are too lenient. This will require processing on a per user basis to remove bias/noise
#
# ### C. Round off scores to the nearest integers. [3 Marks]

# %%
dataset["score"] = dataset["score"].apply(lambda x: round(x, 0) )#, errors = "ignore")

# %% [markdown]
# ### D. Check for missing values. Impute the missing values, if any. [2 Marks]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1415133 entries, 0 to 163836
# Data columns (total 11 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   phone_url  1415133 non-null  object
#  1   date       1415133 non-null  datetime64[ns]
#  2   lang       1415133 non-null  object
#  3   country    1415133 non-null  object
#  4   source     1415133 non-null  object
#  5   domain     1415133 non-null  object
#  6   score      1351644 non-null  float64
#  7   score_max  1351644 non-null  float64
#  8   extract    1395772 non-null  object
#  9   author     1351931 non-null  object
#  10  product    1415132 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(8)
# memory usage: 129.6+ MB

# %%
dataset[dataset["product"].isna() == True]
# Out:
#                                 phone_url       date lang country  source  \
# 312960  /cellphones/samsung-galaxy-s-iii/ 2014-01-22   de      de  Amazon
#
#            domain  score  score_max  \
# 312960  amazon.de   10.0       10.0
#
#                                                   extract author product
# 312960  Bestes Smartphone was ich bisher hatte :) öafk...    NaN     NaN

# %%
dataset[dataset["phone_url"] == "/cellphones/samsung-galaxy-s-iii/"]["product"]
# Out:
# 304429                        Samsung Galaxy S III T-Mobile
# 304430                                 Samsung Galaxy S III
# 304431            Samsung Galaxy S III 16GB (Straight Talk)
# 304432                        Samsung Galaxy S3, Red (AT&T)
# 304433    SAMSUNG Galaxy S III SGH-i747 Blue 3G 4G LTE D...
#                                 ...
# 8910      Schneider, Liane / Wenzel-B??rger, Eva Conni m...
# 8911      Schneider, Liane / Wenzel-B??rger, Eva Conni m...
# 8912      Schneider, Liane / Wenzel-B??rger, Eva Conni m...
# 8913                     Samsung Galaxy S III GT-i9300 16GB
# 8914                     Samsung Galaxy S III GT-I9300 16Gb
# Name: product, Length: 17093, dtype: object

# %%
dataset.loc[312960, "product"] = "Samsung Galaxy S III"

dataset["author"].fillna("unknown", inplace = True)

dataset["extract"].fillna("unavailable or absent", inplace = True)

# %%
dataset["score_max"].value_counts() # Safe to assume that the remaning null columns are also 10
# Out:
# 10.0    1351644
# Name: score_max, dtype: int64

# %%
dataset["score_max"].fillna(10.0, inplace = True)

dataset["score"].fillna(dataset["score"].median(), inplace = True)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1415133 entries, 0 to 163836
# Data columns (total 11 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   phone_url  1415133 non-null  object
#  1   date       1415133 non-null  datetime64[ns]
#  2   lang       1415133 non-null  object
#  3   country    1415133 non-null  object
#  4   source     1415133 non-null  object
#  5   domain     1415133 non-null  object
#  6   score      1415133 non-null  float64
#  7   score_max  1415133 non-null  float64
#  8   extract    1415133 non-null  object
#  9   author     1415133 non-null  object
#  10  product    1415133 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(8)
# memory usage: 161.8+ MB

# %% [markdown]
# ### E. Check for duplicate values and remove them, if any. [2 Marks]

# %%
dataset.drop_duplicates(inplace = True)

dataset.shape
# Out:
# (1405181, 11)

# %%
1415133 - 1405181
# Out:
# 9952

# %% [markdown]
# ### F. Keep only 1 Million data samples. Use random state=612. [2 Marks]

# %%
DATA = dataset.sample(n = 1_000_000, random_state = 612)

DATA.shape
# Out:
# (1000000, 11)

# %% [markdown]
# ### G. Drop irrelevant features. Keep features like Author, Product, and Score. [2 Marks]

# %%
DATA.columns
# Out:
# Index(['phone_url', 'date', 'lang', 'country', 'source', 'domain', 'score',
#        'score_max', 'extract', 'author', 'product'],
#       dtype='object')

# %%
DATA.drop("score_max", axis = 1, inplace = True) # We know the max score for all the records is 10 already

DATA.drop("extract", axis = 1, inplace = True) # Tried my best to preserve it, but can't accomodate the multiple languages

DATA.drop(["source", "domain", "phone_url", "date", "lang"], axis = 1, inplace = True) # Dropping as irrelevant

# %%
DATA.shape
# Out:
# (1000000, 4)

# %% [markdown]
# ## 2. Answer the following questions. [10 Marks]
#
# ### A. Identify the most rated products. [3 Marks]

# %%
most_rated = DATA["product"].value_counts()

most_rated[:10]
# Out:
# Lenovo Vibe K4 Note (White,16GB)       3723
# Lenovo Vibe K4 Note (Black, 16GB)      3084
# OnePlus 3 (Graphite, 64 GB)            2893
# OnePlus 3 (Soft Gold, 64 GB)           2527
# Huawei P8lite zwart / 16 GB            1902
# Samsung Galaxy Express I8730           1891
# Lenovo Vibe K5 (Gold, VoLTE update)    1810
# Samsung Galaxy S6 zwart / 32 GB        1671
# Nokia 5800 XpressMusic                 1530
# Lenovo Vibe K5 (Grey, VoLTE update)    1490
# Name: product, dtype: int64

# %% [markdown]
# ### B. Identify the users with most number of reviews. [3 Marks]

# %%
most_reviews = DATA["author"].value_counts()

most_reviews[:10]
# Out:
# Amazon Customer    54514
# unknown            45137
# Cliente Amazon     13668
# e-bit               6019
# Client d'Amazon     5508
# Amazon Kunde        3290
# Anonymous           1935
# einer Kundin        1894
# einem Kunden        1354
# Anonymous           1006
# Name: author, dtype: int64

# %% [markdown]
# ### C. Select the data with products having more than 50 ratings and users who have given more than 50 ratings. Report the shape of the final dataset. [4 Marks]

# %%
product_gt_50_ratings_user_gt_50_reviews = DATA[DATA["author"].isin(most_reviews[most_reviews > 50].index) &
                                                DATA["product"].isin(most_rated[most_rated > 50].index)]


product_gt_50_ratings_user_gt_50_reviews.shape
# Out:
# (129554, 4)

# %% [markdown]
# ## 3. Build a popularity based model and recommend top 5 mobile phones. [5 Marks]

# %%
top_5 = DATA.groupby("product")["score"].mean().sort_values(ascending = False).head(5)

# %%
for phone, rating in zip(top_5.index, top_5):
    print(f"{phone} : {rating}", "\n\n")
# Out:
# 'Sony Xperia X (F5122) – White – Dual Sim (Google Android 6.0.1, 5 Display, 2 x CORTEX A72 1.8 GHz + 4 x cortex-a53... : 10.0
#
#
# Samsung Galaxy Ace S5830i Smart Phone (plum-purple) : 10.0
#
#
# Samsung Galaxy Core Plus - Smartphone libre Android (pantalla 4.3", cámara 5 Mp, 4 GB, Dual-Core 1.2 GHz), blanco (importado) : 10.0
#
#
# Samsung Galaxy Core Plus (SM-G350) - Smartphone libre Android (pantalla 10.92 cm (4.3"), 480 x 800 Pixeles, TFT, cámara 5 Mp, dual-core a 1.2GHz, 4 GB) Color negro : 10.0
#
#
# Samsung Galaxy Core LTE UK Sim Free Smartphone - Black : 10.0

# %% [markdown]
# ## 4. Build a collaborative filtering model using SVD. You can use SVD from surprise or build it from scratch(Note: Incase you’re building it from scratch you can limit your data points to 5000 samples if you face memory issues). Build a collaborative filtering model using kNNWithMeans from surprise. You can try both user-based and item-based model. [10 Marks]

# %%
from surprise import KNNWithMeans
from surprise import Dataset
from surprise import accuracy
from surprise.model_selection import train_test_split
from surprise import Reader
from surprise import SVD

# %%
final_dataset = DATA.copy()

final_dataset.rename(columns = {
                               "score" : "rating",
                               "author" : "userID",
                               "product" : "itemID"
                               }, inplace = True)
final_dataset.reset_index(inplace = True)
final_dataset.drop("country", axis = 1, inplace = True)

reader = Reader(rating_scale=(0, 10))

final_final_dataset = Dataset.load_from_df(final_dataset[['userID', 'itemID', 'rating']], reader)


train_data, test_data = train_test_split(final_final_dataset, test_size = .25)

# %%
final_dataset.columns
# Out:
# Index(['index', 'rating', 'userID', 'itemID'], dtype='object')

# %% [markdown]
# #### Doing SVD first

# %%
sing_val_decomp = SVD()
sing_val_decomp.fit(train_data)

# %%
predictions = sing_val_decomp.test(test_data)

accuracy.rmse(predictions)
# Out:
# RMSE: 2.4743
# 2.4742638348433363

# %% [markdown]
# #### Doing KNN with means

# %%
knn = KNNWithMeans()
knn.fit(train_data)
# Out:
# Computing the msd similarity matrix...
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22644/2781563746.py in <module>
#       1 knn = KNNWithMeans()
# ----> 2 knn.fit(train_data)
#
# ~\.ipython\lib\site-packages\surprise\prediction_algorithms\knns.py in fit(self, trainset)
#     176
#     177         SymmetricAlgo.fit(self, trainset)
# --> 178         self.sim = self.compute_similarities()
#     179
#     180         self.means = np.zeros(self.n_x)
#
# ~\.ipython\lib\site-packages\surprise\prediction_algorithms\algo_base.py in compute_similarities(self)
#     247             if getattr(self, 'verbose', False):
#     248                 print('Computing the {0} similarity matrix...'.format(name))
# --> 249             sim = construction_func[name](*args)
#     250             if getattr(self, 'verbose', False):
#     251                 print('Done computing similarity matrix.')
#
# ~\.ipython\lib\site-packages\surprise\similarities.pyx in surprise.similarities.msd()
#
# MemoryError: Unable to allocate 1.56 TiB for an array with shape (463596, 463596) and data type float64

# %% [markdown]
# #### I have to reduce the size of data to 100_000 for KNNWithMeans since I don't have 1-2 TiB RAM

# %%
final_dataset = DATA.copy()

final_dataset.rename(columns = {
                               "score" : "rating",
                               "author" : "userID",
                               "product" : "itemID"
                               }, inplace = True)
final_dataset.reset_index(inplace = True)
final_dataset.drop("country", axis = 1, inplace = True)

knn_data = final_dataset.sample(n = 10_000, random_state = 612)

reader = Reader(rating_scale=(0, 10))

final_final_dataset = Dataset.load_from_df(knn_data[['userID', 'itemID', 'rating']], reader)


train_data, test_data = train_test_split(final_final_dataset, test_size = .25)

# %%
knn = KNNWithMeans()
knn.fit(train_data)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.

# %% [markdown]
# ### 5. Evaluate the collaborative model. Print RMSE value. [2 Marks]

# %%
knn_user = KNNWithMeans(sim_options = {"user_based" : True})
knn_user.fit(train_data)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.

# %%
preds_knn_user  = knn_user.test(test_data)
accuracy.rmse(preds_knn_user)
# Out:
# RMSE: 2.5866
# 2.58662714001001

# %%
knn_item = KNNWithMeans(sim_options = {"user_based" : False})
knn_item.fit(train_data)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.

# %%
preds_knn_item = knn_user.test(test_data)
accuracy.rmse(preds_knn_item)
# Out:
# RMSE: 2.5866
# 2.58662714001001

# %% [markdown]
# User-based or Item-based seems to be irrelevant..
#
# ### 6. Predict score (average rating) for test users. [2 Marks]
#
# #### I'm assuming I have to show the estimated rating for each record in the test data

# %%
preds_knn_item
# Out:
# [Prediction(uid='Amazon Customer', iid='Micromax Canvas Knight 2 E471 (Black-Champagne)', r_ui=8.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Erickson Ferreira da Silv', iid='LG Smartphone LG L70 D325 Dual Chip Desbloqueado Android 4.4 Tela...', r_ui=8.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='rosita2', iid='Nokia 3310', r_ui=6.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Paola', iid='Asus ZenFone 3 Smartphone, Display da 5.2", Memoria Interna da 64 GB, 4 GB RAM, Dual-SIM, Nero [Italia]', r_ui=10.0, est=8.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='elisha henningsen', iid='Galaxy Samsung Galaxy Note 4 SM-N910T 4G LTE - 32GB - Charcoal Black (T-Mobile)', r_ui=2.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='lucille55', iid='Apple iPhone 4S 32GB', r_ui=10.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='francesco', iid="Huawei P9 Lite Smartphone, LTE, Display 5.2'' FHD, Processore Octa-Core Kirin 650, 16 GB Memoria Interna, 3GB RAM, Fotocamera 13 MP, Single-SIM, Android 6.0 Marshmallow, Bianco [Italia]", r_ui=10.0, est=10, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='Picci', iid='SAMSUNG Galaxy S5 - blanc - Smartphone', r_ui=10.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Rachel', iid='Samsung E1150 Mobile Phone (Cobble Black)', r_ui=10.0, est=10, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='Amazon Kunde', iid='Huawei P8 lite Dual-SIM Smartphone (5 Zoll (12,7 cm) Touch-Display, 16 GB Speicher, Android 5.0) weiß', r_ui=10.0, est=9.936026936026936, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='alejandro moya lopez', iid='Samsung Galaxy S4 Mini - Smartphone libre Android (pantalla 4.3", cámara 8 Mp, 8 GB, Dual-Core 1.7 GHz, 1.5 GB RAM), blanco', r_ui=8.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='briciolina77', iid='Nokia 5230', r_ui=8.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Peneluc', iid='Samsung Smartphone Samsung Galaxy Y Prata Desbloqueado Claro - GSM, Android 2.3, Processador 832MHz, Câmera de 2MP, 3G, Wi-Fi, Touchscreen 3, Teclado Swype, Cartão de Memória 2GB', r_ui=10.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Puyallupbears ', iid='Samsung Galaxy S4 16GB (Verizon)', r_ui=10.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Селезнев Дмитрий', iid='Samsung Galaxy S III mini GT-I8190 8Gb', r_ui=8.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Keith Shaw', iid='Samsung GT-E1200 - Tel??fono m??vil (3.86 cm (1.52"), 128 x 128 Pixeles, TFT, 32 MB, GSM) Negro', r_ui=6.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Anoop Jha', iid='SAMSUNG Galaxy J5 - 6 (New 2016 Edition) (White, 16 GB)', r_ui=10.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Shivay Arts', iid='OnePlus 3T (Gunmetal, 6GB RAM + 64GB memory)', r_ui=8.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='xceday', iid='Nokia E50 (Metal Black) Cep Telefonu', r_ui=9.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Ronald Fernandez', iid='Samsung S5830 Galaxy Ace Android Powered Smartphone with 5MP Camera, Touch Screen, Wi-Fi - Unlocked Phone - No Warranty - Black', r_ui=6.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='
r_ui=10.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Вячеслав', iid='Lenovo A2010 (белый)', r_ui=9.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Mattsson Fredrik', iid='Sony Xperia ion', r_ui=4.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='CARLINHOS_DOR', iid='Nokia N95 Tampa de bateria', r_ui=10.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Rosa Elaine', iid='Samsung Smartphone Dual Chip Samsung Galaxy S Duos 2 Desbloqueado Branco Android 4.2 3G/Wi-Fi C??mera 5 MP 4GB', r_ui=10.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='MIREILLE', iid='Motorola Moto X 2nd Gen - Unlocked', r_ui=10.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='A. Kulbarts', iid='Samsung SGH-C260 silber-weiss Handy', r_ui=10.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Fu', iid='LG L70 Smartphone - Black', r_ui=9.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='vivenne simpson', iid='HTC Vivid X710a 16GB Unlocked GSM Android Dual-Core Smartphone - White (No Warranty)', r_ui=4.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid="betty o'brien", iid='Samsung T139 Unlocked Phone with Camera, Bluetooth and Speakerphone - Unlocked Phone - US Warranty - Gray', r_ui=2.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Daniel', iid='Motorola Moto G LTE- Factory Unlocked US Warranty (Black)', r_ui=10.0, est=10, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='TrickSiebzehn', iid='HTC Hero Smartphone (Android, 5MP Kamera, GPS, WLAN) weiß', r_ui=8.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='rickster', iid='iPhone 5S APPLE IPHONE 5S 32GB SILVER UNLOCKED', r_ui=2.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Amazon Customer', iid='Samsung Galaxy A8 SM-A800F (Gold) - Scheduled / 4 hour Delivery (Brand Fulfilled)', r_ui=10.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='tobase', iid='Samsung Galaxy S6 Edge 64 GB UK SIM-Free Android Smartphone - White', r_ui=10.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='AvdK', iid='Samsung GT-B2710KRADBT B2710 Smartphone (5,1 cm (2 Zoll) TFT-Farbdisplay, V2.1 Bluetooth, 36MB interne Speicher) schwarz/rot', r_ui=10.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Claudiney Procópio dos Santos Alberto', iid='Smartphone Samsung Galaxy S5 Mini Duos G800H Desbloqueado Preto', r_ui=9.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Cyril Wong', iid='Samsung Note 4 Standard Li-ion Battery 3220mAh for Galaxy Note 4 - Non-Retail Packaging', r_ui=10.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Roxanelle', iid='Apple iPhone 6s 32 GB', r_ui=8.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Zach', iid='HTC G1 Google Android Unlocked Phone with Android OS, Wi-Fi, Bluetooth, 3MP Camera, MicroSD Expansion - Unlocked Phone - US Warranty - Black', r_ui=8.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Gérard', iid='Nokia LUMIA520W Smartphone débloqué Windows Phone Bluetooth Blanc', r_ui=8.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Baybish ', iid='Samsung Galaxy S5 16GB (Verizon)', r_ui=10.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Alex', iid='Sony Xperia Z3 Compact Smartphone (4,6 Zoll (11,7 cm) Touch-Display, 16 GB Speicher, Android 4.4) weiß', r_ui=4.0, est=10, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='Kosumi61 ', iid='Samsung Galaxy J5 ‐Android-puhelin, musta', r_ui=8.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Amazon Customer', iid='Lenovo K3 Note (Black)', r_ui=10.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Amazon Customer', iid='ASUS Zenfone3 Laser 5.5" Unlocked Smartphone, 32GB, Android 6.0', r_ui=8.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Equilibrium', iid='Samsung Galaxy S4', r_ui=10.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Vishal Meena', iid='Motorola Moto E 2nd Generation (3G, White)', r_ui=10.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='smcb66', iid='Vu / CU920 / CU915', r_ui=4.0, est=8.0632, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  ...]

# %% [markdown]
# ### 7. Report your findings and inferences. [2 Marks]
#
# • The error seems to be 2.3-2.5, which could be considered 23-25% since the ratings were out of 10
#
# • There is no difference in error between SVD using 1_000_000 records and KNN using 10_000... Looks like the limit f these         algorithms in this form of the dataset is reached at 10_000 records only... Maybe accuracy could be improved via
#   hyperparameter tuning
#
#
#   ### 8. Try and recommend top 5 products for test users. [5 Marks]

# %%
from collections import defaultdict
def get_top_n(predictions, n):
    # First map the predictions to each user.
    top_n = defaultdict(list)
    for user_id, item_id, true_rate, est_rate, _waste in predictions:
        top_n[user_id].append((item_id, est_rate))

    # Then sort the predictions for each user and retrieve the k highest ones.
    for user_id, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[user_id] = user_ratings[:n]

    return top_n

# %%
top_5_item_based = get_top_n(preds_knn_item, 5)
top_5_user_based = get_top_n(preds_knn_user, 5)
 
top_5_item_based
# Out:
# defaultdict(list,
#             {'Amazon Customer': [('Kyocera DuraXV, Dark Grey 4GB (Verizon Wireless)',
#                10),
#               ('Huawei Honor 5X (Grey, 16GB)', 9.726047537368292),
#               ('OnePlus 3T (Gunmetal, 6GB RAM + 64GB memory)',
#                8.922937885078866),
#               ('YU Yuphoria YU5010A (Black+Silver)', 8.446846953585498),
#               ('YU Yuphoria YU5010A (Black+Silver)', 8.446846953585498)],
#              'Erickson Ferreira da Silv': [('LG Smartphone LG L70 D325 Dual Chip Desbloqueado Android 4.4 Tela...',
#                8.0632)],
#              'rosita2': [('Nokia 3310', 8.0632)],
#              'Paola': [('Asus ZenFone 3 Smartphone, Display da 5.2", Memoria Interna da 64 GB, 4 GB RAM, Dual-SIM, Nero [Italia]',
#                8.0)],
#              'elisha henningsen': [('Galaxy Samsung Galaxy Note 4 SM-N910T 4G LTE - 32GB - Charcoal Black (T-Mobile)',
#                8.0632)],
#              'lucille55': [('Apple iPhone 4S 32GB', 8.0632)],
#              'francesco': [("Huawei P9 Lite Smartphone, LTE, Display 5.2'' FHD, Processore Octa-Core Kirin 650, 16 GB Memoria Interna, 3GB RAM, Fotocamera 13 MP, Single-SIM, Android 6.0 Marshmallow, Bianco [Italia]",
#                10)],
#              'Picci': [('SAMSUNG Galaxy S5 - blanc - Smartphone', 8.0632)],
#              'Rachel': [('Samsung E1150 Mobile Phone (Cobble Black)', 10)],
#              'Amazon Kunde': [('Huawei P8 lite Dual-SIM Smartphone (5 Zoll (12,7 cm) Touch-Display, 16 GB Speicher, Android 5.0) weiß',
#                9.936026936026936),
#               ('Doogee X5 MAX, 4000mAh große Batterie, 8MP + 8MP Dual-Kamera, Fingerabdruck, Android 6.0, 5 Zoll HD LCD, dual SIM, Smartphone ohne Vertrag (Weiß)',
#                8.0632),
#               ('Wiko 9593 Fever Smartphone (13,2 cm (5,2 Zoll), 4G, 16GB, 1920x1080 Pixel, 13 Megapixel, Android) weiß/champagner',
#                8.0632),
#               ('LG G5 silber - Mobiltelefon - Google Android', 8.0632),
#               ('Apple iPhone SE Smartphone (4 Zoll (10,2 cm) Touch-Display, 16 GB Speicher, IOS) gold',
#                8.0632)],
#              'alejandro moya lopez': [('Samsung Galaxy S4 Mini - Smartphone libre Android (pantalla 4.3", cámara 8 Mp, 8 GB, Dual-Core 1.7 GHz, 1.5 GB RAM), blanco',
#                8.0632)],
#              'briciolina77': [('Nokia 5230', 8.0632)],
#              'Peneluc': [('Samsung Smartphone Samsung Galaxy Y Prata Desbloqueado Claro - GSM, Android 2.3, Processador 832MHz, Câmera de 2MP, 3G, Wi-Fi, Touchscreen 3, Teclado Swype, Cartão de Memória 2GB',
#                8.0632)],
#              'Puyallupbears ': [('Samsung Galaxy S4 16GB (Verizon)', 8.0632)],
#              'Селезнев Дмитрий': [('Samsung Galaxy S III mini GT-I8190 8Gb',
#                8.0632)],
#              'Keith Shaw': [('Samsung GT-E1200 - Tel??fono m??vil (3.86 cm (1.52"), 128 x 128 Pixeles, TFT, 32 MB, GSM) Negro',
#                8.0632)],
#              'Anoop Jha': [('SAMSUNG Galaxy J5 - 6 (New 2016 Edition) (White, 16 GB)',
#                8.0632)],
#              'Shivay Arts': [('OnePlus 3T (Gunmetal, 6GB RAM + 64GB memory)',
#                8.0632)],
#              'xceday': [('Nokia E50 (Metal Black) Cep Telefonu', 8.0632)],
#              'Ronald Fernandez': [('Samsung S5830 Galaxy Ace Android Powered Smartphone with 5MP Camera, Touch Screen, Wi-Fi - Unlocked Phone - No Warranty - Black',
#                8.0632)],
#              'Gartenzwerg': [('Nokia E5-00 Smartphone (6cm (2,3 Zoll) Display, Bluetooth, 5 Megapixel Kamera) [EU-Version] schwarz',
#                8.0632)],
#              '#': [('Nokia 5530 XpressMusic', 10), ('Nokia 8800', 9.0)],
#              'Simone': [('Sony Ericsson W595 Handy (Bluetooth, 3.2MP, 2GB Memory Stick, Walkman, UKW-Radio) Peachy Pink',
#                8.0632)],
#              'Tom': [('Samsung Galaxy S5 SM-G900F 16GB Factory Unlocked Cellphone International Version, Retail Packaging, Black',
#                10)],
#              'Sonata': [('Apple iPhone 8Go Noir', 8.0632)],
#              'Little-J': [('Huawei Ascend Y530 Smartphone (4,5 Zoll (11,4 cm) Touch-Display, 4 GB Speicher, Android 4.3) weiß',
#                8.0632)],
#              'Amit Tyagi': [('HTC Desire 816G+ Octa-core (Dual SIM, 16GB, Blue)',
#                8.0632)],
#              'Marissa G': [('LG G3 D850 32GB Unlocked Smartphone, GSM 4G LTE-Quad-HD, 5.5-Inch,(Metallic Black)',
#                8.0632)],
#              'CocolicheDG': [('Motorola Moto G4 Plus (16GB, black)', 8.0632)],
#              'Virtualnetwork': [('BLACKBERRY Bold 9700', 8.0632)],
#              'FrancoP62': [('Samsung Galaxy S4 Mini Black Edition Smartphone, LTE, Display 4.3 Pollici, Memoria Interna 8 GB, Fotocamera 8 MP, micro-SIM, NFC, Android 4.2, Nero [Germania]',
#                8.0632)],
#              'Antonio': [('Alcatel OT 991D Smartphone, Nero [Italia]', 8.0632),
#               ('HTC One M8 Mini 2 Smartphone, Argento [Italia]', 8.0632),
#               ('Sony Xperia Z1 - Smartphone libre Android (pantalla 5", cámara 20.7 Mp, 16 GB, 2.2 GHz, 2 GB RAM), blanco (importado)',
#                5.0)],
#              'Massimo Telch': [('Huawei Ascend G7 Smartphone, 16 GB, Argento',
#                8.0632)],
#              'thunder': [('Apple iPhone 5 Unlocked Cellphone, 32GB, Black',
#                10)],
#              'oapdm': [('LG G6', 8.0632)],
#              'Вера': [('Apple iPhone 5s 16GB (серебристый)', 10)],
#              'bear': [('Sony Ericsson Xperia X10 Sim Free Mobile Phone - Black (discontinued by manufacturer)',
#                8.0632)],
#              'Sachin Kulkarni': [('Lenovo Vibe K5 Plus (Dark Grey, 16 GB)',
#                8.0632)],
#              'Smoky-Georgi-Grendel': [('LG Optimus L90 D415 8GB Unlocked GSM Quad-Core Android Smartphone - Graphite Gray',
#                8.0632)],
#              'DerB': [('Samsung N920C Factory Unlocked GSM Galaxy Note 5, 32GB - International Version (Black)',
#                8.0632)],
#              'G. V.': [('Samsung Galaxy S5 Unlocked Gsm Android Phone 4g LTE 16gb - International Version (Copper Gold)',
#                8.0632)],
#              'ALVARADO_V2005': [('Motorola A1200i', 8.0632)],
#              'mario': [('OnePlus ONE SANDSTONE BLACK 64 GB Smartphone CyanogenMod CM11 Qualcomm Snapdragon 801 8974AC 4G 2.5GHz Quad Core LTE 3GB 5.5 Gorilla Glass FHD',
#                8.0632),
#               ('Alcatel One Touch 20-04G Telefono Cellulare, Nero', 8.0)],
#              'Gabriele Fubiani': [('Nokia Lumia 530 Smartphone, 4 GB, Marchio TIM, Grigio [Italia]',
#                8.0632)],
#              'Lostpiecezoflove': [('Sanyo SCP-200', 8.0632)],
#              'Cindy2401': [('Siemens A55', 8.0632)],
#              'And': [('Honor 6 4G UK Smartphone (5 inch, Touchscreen, Octa-Core, 3GB RAM, 16GB ROM, 13MP rear camera, 5MP front camera, LTE CAT6, Android 4.4, EmotionUI 2.3) Black',
#                8.0632)],
#              'TCHANEZ': [('Samsung T519', 8.0632)],
#              'PeterKi': [('iPhone 6 16 GB - space grey', 8.0632)],
#              'Joesy': [('Vodafone Smart Prime 6 Pay As You Go Handset Smartphone - Anthracite',
#                8.0632)],
#              'Luis Carlos': [('Samsung OMNIA W', 8.0632)],
#              'Cynthia Letts': [('Samsung SGH-T619', 8.0632)],
#              'unknown': [('Sony Ericsson K810i', 9.840635268346112),
#               ('Sony Ericsson K810i', 9.840635268346112),
#               ('Nokia 6300', 9.278171509567683),
#               ('Samsung Galaxy Mini GT-S5570', 9.123493975903614),
#               ('Samsung Galaxy Mini GT-S5570', 9.123493975903614)],
#              'adele295': [('ZTE Warp (Boost Mobile)', 8.0632)],
#              'colin price': [('Doro PhoneEasy 612i GSM Sim Free Mobile Phone - Aubergine',
#                8.0632)],
#              'BEBOUNE4': [('Samsung SGH E900 Noir', 8.0632)],
#              'Shin ': [('LG D855', 8.0632)],
#              'maite': [('Sony Xperia Neo V - Smartphone libre Android (pantalla t??ctil de 3,7" 854 x 480, c??mara 5 MP, 320 MB de capacidad) color negro [importado de Alemania]',
#                8.0632)],
#              "Harry's Memo": [('Nokia Microsoft Lumia 640 Windows 8.1 Phone, 4G LTE 5 Inch Display 1GB RAM 8GB ROM (AT&T Go Phone No Annual Contract)',
#                8.0632)],
#              'RECORDSTORE': [('Nokia N97', 8.0632)],
#              'N Swaminathan': [('Mi 4i (Grey, 16GB)', 8.0632)],
#              'Temppuli': [('Apple iPhone SE 64 Gt ‐puhelin, ruusukulta',
#                8.0632)],
#              'Shreyaan Seth': [('OnePlus 3 (Graphite, 64 GB)', 8.0632)],
#              'SlyFox': [("Sony Mobile Station d'accueil DK48 - s'adapte Xperia Z3, Xperia Z3 Compact",
#                8.0632)],
#              'alain': [('Samsung Galaxy Y Pro Téléphone portable Android 2.3 Gingerbread GSM/GPRS/EDGE 3G Bluetooth Gris',
#                8.0632)],
#              'rahul': [('Microsoft Lumia 535 (White, Dual SIM, 8GB)', 8.0632)],
#              'Wade Tarr': [('Samsung Galaxy Centura Android Prepaid Phone (TracFone)',
#                8.0632)],
#              'Doreen Weber': [('Huawei P8 lite Dual-SIM Smartphone (5 Zoll (12,7 cm) Touch-Display, 16 GB Speicher, Android 5.0) schwarz',
#                8.0632)],
#              'D. Hörner': [('Samsung Galaxy Alpha Smartphone (4,7 Zoll (11,9 cm) Touch-Display, 32 GB Speicher, Android 4.4) blau',
#                8.0632)],
#              'Luciana Patuelli': [('thl T100s Smartphone MTK6592 8-Core Android 4.2 OS NFC OTG 2G RAM 5.0 pollici Schermo FHD - Nero',
#                8.0632)],
#              'mao13': [('LG OPTIMUS L5 II E460 BLACK VODAFONE ITALIA',
#                8.0632)],
#              'R. Kopp "ppok"': [('Huawei Ascend Y530 Smartphone (4,5 Zoll (11,4 cm) Touch-Display, 4 GB Speicher, Android 4.3) weiß',
#                8.0632)],
#              'Tony S.': [('BlackBerry Q10 Unlocked Cellphone, 16GB, White',
#                8.0632)],
#              'Shivam Thukral': [('YU Yuphoria YU5010A (Black+Silver)',
#                8.0632)],
#              'Arputharaj Victor': [('Nokia Lumia 822 GSM Unlocked GSM Windows Phone - White',
#                8.0632)],
#              'renenri': [('Nokia C5', 8.0632)],
#              'LSM66': [('Samsung U600', 8.0632)],
#              '2H': [('Sony Ericsson K220i', 8.0632)],
#              'Not Elvis': [('Nokia Microsoft Lumia 640 Windows 8.1 Phone, 4G LTE 5 Inch Display 1GB RAM 8GB ROM (AT&T Go Phone No Annual Contract)',
#                8.0632)],
#              'Volli': [('Nokia 6310i silver (GPRS, Bluetooth, HSCSD, WAP, Java) Handy',
#                8.0632)],
#              'roberto': [('Nokia Lumia 520 Smartphone, Black [Italia]', 10)],
#              'Jim': [('LG Electronics Nexus 5 UK Smartphone - Black (16GB)',
#                8.0632)],
#              'Melissa': [('Samsung Convoy 3 SCH-U680 Rugged 3G Cell Phone Verizon Wireless',
#                8.0632)],
#              'Sujith': [('Blackberry Z3', 8.0632)],
#              'circee99': [('Samsung SGH E330', 8.0632)],
#              'Seth A.': [('Dell Venue Pro Phone 8 GB with Windows 7 Operating System, 5MP Camera for ATT Network',
#                8.0632)],
#              'Manushankar': [('Asus Zenfone 2 Laser ZE500KL (Black, 8GB)',
#                8.0632)],
#              'Dirk': [('Samsung Galaxy J5 Smartphone (5 Zoll (12,7 cm) Touch-Display, 8 GB Speicher, Android 5.1) weiß',
#                8.0632)],
#              'Papalova Michaela': [('Huawei P8 Lite DS (SP-P8LITEDSBOM) černý',
#                8.0632)],
#              'Xana': [('Sony Xperia P Smartphone (10,2 cm (4 Zoll) Touchscreen, 8 Megapixel Kamera, Android 4.0 OS) rot',
#                8.0632)],
#              'DaRev1': [('3220', 8.0632)],
#              'craneman': [('Samsung Galaxy Rugby | Red and Black', 8.0632)],
#              'Douglas McArthur': [('Apple iPhone 4 Verizon Cellphone, 16GB, White',
#                8.0632)],
#              'gisele santana': [('Smartphone Motorola Moto X 2ª Geração XT1097 32 GB',
#                8.0632)],
#              'Алый цветик': [('Sony Xperia SP (красный)', 8.0632)],
#              'Fede': [('Nokia C2-05', 8.0632)],
#              'Jackie': [('Pantech Hotshot CDM8992 Verizon CDMA Phone with Touchscreen, 3.15MP Camera, Video, GPS, Bluetooth, MP3/MP4 Player and microSD Slot - Red',
#                8.0632)],
#              'Swapnil Pawar': [('Lenovo Vibe P1 Turbo (Sliver)', 8.0632)],
#              'Arthur': [('Microsoft Nokia 2730 classic Handy (MP3, UMTS, Opera Mini, Bluetooth) black',
#                8.0632)],
#              'balkyboo': [('Ericsson T20s', 8.0632)],
#              'menslife': [('Nokia 8210', 8.0632)],
#              'SATHISH': [('Lenovo A1000 (White)', 8.0632)],
#              'Alex': [('Sony Xperia Z1 (белый)', 10),
#               ('Sony Xperia Z3 Compact Smartphone (4,6 Zoll (11,7 cm) Touch-Display, 16 GB Speicher, Android 4.4) weiß',
#                10),
#               ('HTC Incredible S', 10)],
#              'скутельская ангелина': [('Sony Ericsson Z610i', 8.0632)],
#              'swedexx': [('Samsung Galaxy S III mini', 8.0632)],
#              'Bhargesh Ved': [('Lenovo Vibe K4 Note (Black, 16GB)', 8.0632)],
#              'Bernd Appel': [('Samsung Galaxy S5 Smartphone (5,1 Zoll (12,9 cm) Touch-Display, 16 GB Speicher, Android 4.4) electric blue',
#                8.0632)],
#              'bernardi': [('Nokia Microsoft Lumia 535 Smartphone débloqué 3G (Ecran : 5 pouces - 8 Go - Double SIM - Windows Phone 8.1) Noir',
#                8.0632)],
#              'guidindong': [('E380', 8.0632)],
#              'Manoj Mistry': [('Microsoft Lumia 640 UK SIM-free 5 inch Windows Smartphone - Orange',
#                8.0632)],
#              'Coincity': [('ZTE Blade S6 LTE - Smartphone de 5" (4G, Qualcomm MSM8939 Octa Core doble SIM, 2 GB RAM, 16 GB ROM, cámara frontal de 5 Mp, cámara trasera 13 Mp, Android 5.0 Lollipop) color plateado',
#                8.0632)],
#              'Tobias Jung': [('T-Mobile G1 schwarz Smartphone (T-Mobile Branding)',
#                8.0632)],
#              'Mel': [('Motorola MB300 Backflip Unlocked 3G Android Phone with 5 MP Camera, Wi-Fi, GPS Navigator and Bluetooth - Silver',
#                8.0632)],
#              'Sonja': [('Samsung Galaxy S7 Edge 32GB Rosa Gull', 8.0632)],
#              'Ivan': [('HTC One M8 16GB 4G LTE Unlocked GSM Android Cell Phone EMEA Version - Silver',
#                8.0632)],
#              'VLAD RAZVAN IONUT': [('Huawei Mate 7 - Smartphone libre Android (pantalla 6", cámara 13 Mp, 16 GB, Quad-Core 1.8 GHz, 2 GB RAM), blanco',
#                8.0632)],
#              'Luca': [('Samsung Galaxy A5 2016 Smartphone LTE, 16GB, Nero',
#                7.5),
#               ('Samsung I9060i Galaxy Grand Neo Plus Smartphone, 8 GB, Bianco [Italia]',
#                7.5)],
#              'Mausi': [('Microsoft Nokia 6210 Navigator black (UMTS, GPS, A-GPS, MP3, Speicherkarte, Navigationslizenz Kamera mit 3,2 MP) UMTS Handy',
#                8.0632)],
#              'Mrs Sara Bracher': [('ZOPO ZP980 - 5.0 Inch FHD (1980 x 1080px) 1080P Screen Android 4.2 Smartphone quad core 1.5GHz MTK6589T 2GB RAM...',
#                8.0632)],
#              'Diogo': [('Apple iPhone 3G S (32GB)', 8.0632)],
#              'Amazon Product Consumer': [('LG enV2 VX-9100 Black QWERTY Cell Phone for Verizon Wireless',
#                8.0632)],
#              'Gabriele F.': [('LG D405 L90 Smartphone, 8 GB, Nero [Italia]',
#                8.0632)],
#              'ffedorlegrand2009': [('Nokia 7310 Supernova', 8.0632)],
#              'Sandra': [('Sony Ericsson Cedar Handy (UMTS, HSDPA, 2MP, 3.5mm Klinkenstecker, Micro-USB Anschluss) schwarz/silber',
#                8.0632),
#               ('Sony Ericsson Elm Handy (UMTS, aGPS, Bluetooth, WiFi, 5MP) metal black',
#                8.0632)],
#              'Razdelkin Stanislav': [('Nokia Lumia 800', 8.0632)],
#              'BLAS CARRILLO': [('OneTouch New Factory Unlocked Alcatel OneTouch Evolve, Black, International GSM Android Phone, Unlocked to work with AT&T, T-Mobile, Simple Mobile, Ultra Mobile, Family Mobile all GSM Network worldwide',
#                8.0632)],
#              'danielclark691': [('Alcatel One Touch 311', 8.0632)],
#              'Sven': [('Acer Liquid Z530 Dual-SIM LTE Smartphone (12,7 cm (5 Zoll) IPS HD Zero-Air-Gap Display, 1280 x 720 Pixel, Quad-Core-Prozessor, 8 Megapixel, 1GB RAM, 8GB Speicher, Android 5.1) schwarz',
#                8.0632)],
#              'Mary B.': [('Samsung Galaxy S6 32GB SM-G920i - Unlocked White (International Version)',
#                8.0632)],
#              'Finbar': [('Sim Free Apple iPhone SE 64GB Mobile Phone - Gold',
#                8.0632)],
#              'flyingaho': [('Verizon Motorola Moto Q - Smartphone - CDMA2000 1X - bar - Windows Mobile - silver - Verizon',
#                8.0632)],
#              'David': [('Nokia Lumia 920 RM-820 32GB Unlocked GSM 4G LTE Windows Smartphone - Black',
#                8.0632)],
#              'Alessandro G.': [('Huawei P8 lite Smartphone, Display 5.0" IPS, Dual Sim, Processore Octa-Core, Memoria 16 GB, Fotocamera 13 MP, Android 5.0, Bianco',
#                8.0632)],
#              'castiza22': [('Nokia 2300', 8.0632)],
#              'Coskun': [('LG Electronics KP500 Cookie Smartphone (7.6 cm (3.0 Zoll) TFT-Touchscreen, 3MP Kamera, QWERTZ-Tastatur) schwarz Handy ohne Branding',
#                8.0632)],
#              'Giulia': [('BlackBerry Q5 LTE QWERTZ, Rosa', 8.0632)],
#              'msu-xalba': [('HTC Wildfire', 8.0632)],
#              'gerard hughes': [('Cubot P9 5.0 inch QHD Google Android 4.2 Unlocked 3G Smartphone MTK6572 Dual Core Dual SIM Dual Standby SIM-Free...',
#                8.0632)],
#              'socha20 ': [('Samsung Galaxy S5 16GB (Verizon)', 8.0632)],
#              'Simon': [('LG Electronics E975 Optimus G Smartphone (11,9 cm (4,7 Zoll) Touchscreen, Quad-Core, 1,5GHz, 13 Megapixel Kamera, microUSB, Android 4.1) schwarz',
#                10)],
#              'Lozza': [('Samsung Galaxy S3 mini', 8.0632)],
#              'nonic_data': [('LG Electronics P710 Optimus L7 II Smartphone (10,9 cm (4,3 Zoll) Touchscreen, 1GHz, Dual-Core, 4GB, 768MB RAM, 8-Megapixel-Kamera, Android 4.1) metallisch-schwarz',
#                10),
#               ('elephone P8000 4G Smartphone MTK6753 64bit Octa Core Touch ID 5,5 Pollici FHD 3GB RAM 16GB ROM 13MP Fotocamera 4165mAh Battery Grigio',
#                10),
#               ("Huawei P9 Lite Smartphone, LTE, Display 5.2'' FHD, Processore Octa-Core Kirin 650, 16 GB Memoria Interna, 3GB RAM, Fotocamera 13 MP, Single-SIM, Android 6.0 Marshmallow, Nero [Italia]",
#                9.310124049619848),
#               ('Alcatel One Touch 20-04G Telefono Cellulare, Nero',
#                8.156862745098039),
#               ('Blackview BV5000 Lte 4G- Smartphone Libre Android Impermeable Ip67 (5.0" Hd, 5000mAh, 64 Bits quad Core, 16Gb, 2Gb Ram, 13Mp, Dual Sim, Antipolvo Antigolpes), Naranja',
#                8.156862745098039)],
#              'Luisa': [('BlackBerry Curve 9320 Unlocked GSM OS 7.1 Smartphone - Black',
#                8.0632)],
#              'Distary': [('Nokia 6700 Classic', 8.0632)],
#              'SepiBMY ': [('Huawei Ascend P7 Android-puhelin, valkoinen',
#                8.0632)],
#              'Linda_90': [('Samsung Galaxy S6 wit / 32 GB', 8.0632)],
#              'Kigen ': [('Samsung Galaxy S6 edge+ 64GB (Verizon)', 8.0632)],
#              'DS': [('Samsung Galaxy Centura Android Prepaid Phone (TracFone)',
#                8.0632)],
#              'Jennileigh': [('Apple iPhone 5s T-Mobile Cellphone, 16GB, Space Gray',
#                8.0632)],
#              'Ralph': [('Tracfone LG TracFone 306G No Contract, 2.0 megapixel Camera, 3.2-Inch screen, Black, Retail Packaging',
#                10)],
#              'scott houston': [('Motorola Droid X2 No Contract Verizon Cell Phone',
#                8.0632)],
#              'Sashe Neshikj': [('Samsung Factory Unlocked Samsung Galaxy S5 SM-G900H black 16GB International Version',
#                8.0632)],
#              'Andrea Hamburger': [('Honor 6 Smartphone (5 Zoll (12,7 cm) Touch-Display, 16 GB Speicher, Android 4.4) schwarz',
#                8.0632)],
#              'Amazon Kundenrezensionen': [('Microsoft Nokia Lumia 830 Smartphone (5 Zoll (12,7 cm) Touch-Display, 16 GB Speicher, Windows 8.1) orange',
#                8.0632)],
#              'Gaston D.': [('Nokia Unlocked Microsoft Nokia Lumia 635 RM-975, Black',
#                8.0632)],
#              'L. Sharpe': [('Xperia Sony Xperia SP SIM-free Android Smartphone - White (discontinued by manufacturer)',
#                8.0632)],
#              'Elijah Ungvary': [('Sprint Samsung Galaxy S5 White 16GB (Sprint Prepaid)',
#                8.0632)],
#              'Emanuele Franco': [('Huawei Y6 Smartphone, Display 5.0" HD, IPS, 2 GB RAM, 8 GB Memoria Interna, Dual SIM, Fotocamera 8 MP, Android 5.1, Nero',
#                8.0632)],
#              'Рукавишников Антон': [('Samsung Galaxy Core 2 SM-G355H',
#                8.0632)],
#              'Larry131313': [('Motorola Moto Z Play Droid', 8.0632)],
#              'samantha27': [('Samsung Galaxy S6 zwart / 32 GB', 8.0632)],
#              'Emanuela Rastrelli': [('BlackBerry Z30 - bianco - QWERTY - Smartphone',
#                8.0632)],
#              'vinayryder13': [('Samsung Galaxy S5', 8.0632)],
#              'sven schlegel': [('Samsung Star S5230 Smartphone (Touchscreen, 3MP Kamera, Video, MP3-Player, Bluetooth) black gold',
#                8.0632)],
#              'Qantas': [('Sony, Sony Ericsson K850i', 8.0632),
#               ('Samsung Galaxy Express I8730', 4.0)],
#              'liliana': [('LG D320 L70 Smartphone, 4 GB, Bianco [Italia]',
#                8.0632)],
#              'Siddhartha B.': [('HTC Desire 10 Lifestyle (Stone Black, 32 GB) - with Hi-res earphones',
#                8.0632)],
#              'S. Koch': [('HTC P4350 (Herald) Smartphone Handy', 8.0632)],
#              'Анатолий': [('Sony Xperia Z C6602 White', 8.0632)],
#              'Jon Smarsh': [('Lenovo Vibe K4 Note (Black, 16GB)', 8.0632)],
#              'сибоб': [('Samsung C260', 8.0632)],
#              'BRIZUCA100': [('LG GX200', 8.0632)],
#              'HITECH': [('Lumia 925', 8.0632)],
#              'анубис': [('Nokia N95', 8.0632)],
#              'Wolfgang Zepf': [("Samsung S8300 UltraTOUCH (2.8'' Touchscreen AMOLED, 8 MP-Kamera, UMTS/HSDPA) noble black Handy",
#                8.0632)],
#              'Rustaye': [('Apple iPhone 7 Plus, 32Gb - Rose Gold', 8.0632)],
#              'Merola': [("Membrane Ultra Slim Noir Cuir Étui Coque pour Sony Xperia M (Experia C1904/C1905) - Flip Case Cover Pochette + 2 Films de protection d'écran",
#                8.0632)],
#              'Halycon Cent': [('Samsung Galaxy S Plus I9001 Smartphone (10,16 cm (4 Zoll) Display, Touchscreen, 5 Megapixel Kamera, Android Betriebssystem) ceramic weiß',
#                8.0632)],
#              'ip_86': [('Samsung GT-C3200 Monte Bar', 8.0632)],
#              "Client d'Amazon": [("Huawei P9 lite Smartphone débloqué 4G [Version Europe de l'Ouest] or",
#                8.0632),
#               ('Meizu M2 Note Smartphone débloqué 4G (Ecran: 5,5 pouces - 16 Go - Double Nano-SIM - Android 5.1 Lollipop) Blanc',
#                8.0632),
#               ('HTC Desire 610 Smartphone débloqué 4G (Ecran: 4.7 pouces - 8 Go - Android 4.4 KitKat) Bleu',
#                8.0632),
#               ("Samsung Galaxy A5 2016 Smartphone débloqué 4G (Ecran: 5,2 pouces - 16 Go - Simple Nano-SIM - Android) Rose d'Or",
#                8.0632),
#               ('Samsung Galaxy J7 Smartphone débloqué 4G Noir', 8.0632)],
#              'jose argueta': [('Microsoft Lumia 950 XL RM-1085 32GB White, Single Sim, 5.7", 20MP, 3GB Ram, Unlocked International Model, No Warranty',
#                8.0632)],
#              'berfin': [('HTC (187) Explorer', 8.0632)],
#              'SERGGIAM': [('Nokia N97', 8.0632)],
#              'carlo brambilla': [('Huawei Ascend G700 Smartphone Dual SIM, Nero',
#                8.0632)],
#              'Мочкодан Вадим Володимирович': [('Nokia 5800', 8.0632)],
#              'iceblu_78': [('HTC One Max 16GB', 8.0632)],
#              'zerotsm': [('6030', 8.0632)],
#              'DieselTreso': [('CAT S60', 8.0632)],
#              'TMR54 ': [('Samsung Galaxy S5 16GB (AT&T)', 8.0632)],
#              'Kristin': [('Samsung Epic 4G Touch Galaxy S II SPH-D710 Black Smartphone Sprint',
#                8.0632)],
#              'MerryZombie': [('Nokia C3', 8.0632)],
#              'Eric ': [('CAT S30 4.5 inch Dual-SIM LTE outdoor smartphone Android 5.1 Lollipop 1.1 GHz Quad Core Zwart',
#                8.0632)],
#              'starscream': [('v60i (GSM) / v60gi', 8.0632)],
#              'codjo': [('SAMSUNG B3410 Rose', 8.0632)],
#              'GDA': [('Asus ZenFone 2 Laser Smartphone, Display da 5", 16 GB, Dual SIM, Nero [Italia]',
#                8.0632)],
#              'Long': [('Sharp Aquos Crystal, Sprint (Silver)', 8.0632)],
#              'Art2693 ': [('Samsung Galaxy S7 edge 32GB (T-Mobile)', 8.0632)],
#              'Janzn': [('Nokia 5510', 8.0632)],
#              'григорьев иван': [('Acer Liquid E1 Duo', 8.0632)],
#              'Alexp': [('??????????????? Apple iPhone 5', 8.0632)],
#              'дамир': [('Samsung S5660 Galaxy Gio', 8.0632)],
#              'Геннадий': [('Sony Xperia Z (черный)', 8.0632)],
#              'fifi': [('Samsung Behold T-919', 8.0632)],
#              'Kavish Bedi': [('LG Optimus L3 Dual E405 - Black', 8.0632)],
#              'barneystinson': [('HTC Sensation', 8.0632)],
#              'George': [('Nokia N71', 10)],
#              'gianfranco': [('DOOGEE X5 Max Pro Smartphone, 5 Pollici HD IPS Display, 4G Android 6.0 Telefono Cellulari Doppia SIM - 16 GB Memoria Interna 2GB RAM - Fotocamera 8.0MP - 4000mAh Impronta Digitale Cellulare - Nero',
#                8.0632)],
#              'alfredo': [('Huawei Mate S Premium - Smartphone libre Android (pantalla 5.5", Octa-Core, 3 GB de RAM, 128 GB, cámaras de 13 Mp) color dorado',
#                8.0632)],
#              'INOX2005': [('Sony Ericsson W395', 8.0632)],
#              'EvdS': [('Huawei P8lite zwart / 16 GB', 8.0632)],
#              'Maxou62137': [('Samsung U600', 8.0632)],
#              'Глеб': [('Apple iPhone 5s (16GB)', 8.0632)],
#              'M CARMEN CANTERO LAGOSTENA': [('BQ Aquaris E4.5 - Smartphone de 4.5 pulgadas (3G, WiFi 802.11 b/g/n, Bluetooth 4.0 NFC HCE, GPS, 1 GB de RAM, memoria interna de 8 GB), negro - (Reacondicionado Certificado) por BQ',
#                8.0632)],
#              'LauraLLC': [('Samsung Star 3 Duos S5220', 8.0632)],
#              'Christian dior dabidjan': [('BlackBerry Curve 9380', 8.0632)],
#              'Manuel Hausmann': [('Samsung Galaxy S4 Smartphone 5 Zoll, 16 GB, Android 4.2',
#                8.0632)],
#              'Alfonso': [('Motorola Moto G (3ª Generación) + Carcasa Oficial color turquesa - Smartphone libre Android 6 (4G, pantalla 5", cámara 13 Mp, 16 GB, Quad Core 1.4 GHz, 2 GB de RAM), negro',
#                8.0632),
#               ('Samsung Galaxy S II Bianco - GT-I9100, garanzia italiana',
#                8.0632),
#               ('Samsung Galaxy S6 edge SM-G925F 32GB 4G Color blanco - Smartphone (SIM única, Android, NanoSIM, EDGE, GPRS, GSM, HSPA, HSPA+, UMTS, LTE)',
#                8.0632)],
#              'Jsims97 ': [('Samsung Galaxy S6 edge+ 64GB (AT&T)', 8.0632)],
#              'Kislay Kumar': [('Nokia Asha 501 (Dual SIM, Bright Red)',
#                8.0632)],
#              'Félix': [('Samsung Omnia W I8350', 8.0632),
#               ('Sony Xperia L - Smartphone libre Android (pantalla 4.3", cámara 8 Mp, 8 GB, Dual-Core 1 GHz, 1 GB RAM), blanco (importado)',
#                8.0632)],
#              'Carlos': [('Lenovo Moto G4 Plus Smartphone (14 cm (5,5 Zoll), 16GB, Android) schwarz',
#                8.0632),
#               ('LG K4', 8.0632)],
#              'Jokatron': [('Samsung GT-B2710KRADBT B2710 Smartphone (5,1 cm (2 Zoll) TFT-Farbdisplay, V2.1 Bluetooth, 36MB interne Speicher) schwarz/rot',
#                8.0632)],
#              'marc': [('Xiaomi MI 4 - Smartphone libre Android (pantalla 5", cámara 13 Mp, 16 GB, Quad-Core 2.5 GHz, 3 GB RAM), blanco',
#                8.0632)],
#              'zehrabalta': [('Blackberry Storm 9530 Cep Telefonu', 8.0632),
#               ('Nokia E50 Cep Telefonu', 8.0632)],
#              'thomas': [('Samsung Galaxy S Duos Smartphone, Dual SIM, Bianco [Europa]',
#                8.0632)],
#              'A.W.': [('Tech Armor Galaxy S6 Screen Protector, Tech Armor High Definition HD-Clear Samsung Galaxy S6 Film Screen Protector [3-Pack]',
#                8.0632)],
#              'Пользователь скрыл свои данные': [('Sony Xperia Z5', 8.0632),
#               ('Apple iPhone 7 Plus 128Gb', 8.0632)],
#              'Demo1988': [('LG Cookie WiFi T310i', 8.0632)],
#              'wiesman1000': [('Pantech Matrix C740 Unlocked GSM Phone with Dual-Sliding Keypad, Full QWERTY Keyboard, 1.3MP Camera, Bluetooth and microSD Slot - Blue',
#                8.0632)],
#              'Aceliau': [('Smartphone Sony Xperia E3 Dual Chip Desbloqueado Android 4.4 Tela 4.5 4GB Câmera de 5MP GPS - Preto',
#                8.0632)],
#              'Nash.Bridges': [('Samsung SGH-E950', 8.0632)],
#              'dean jackson': [('Nokia C2-05 Sim Free Mobile Phone - Dark Grey',
#                8.0632)],
#              'rajesh': [('Nokia N97', 8.0632)],
#              'Eric Chaffey': [('Asus ZenFone 2 Unlocked Cellphone , 64GB, Silver (U.S. Warranty)',
#                8.0632)],
#              'Nicole K.': [('Microsoft Nokia Asha 311 Smartphone (7,6 cm (3 Zoll) Touchscreen, 3,2 Megapixel Kamera, GPS) pink',
#                10)],
#              'Testerhans': [('ZTE Axon 7 Mini Smartphone (13,2 cm (5,2 Zoll) Display, 32 GB Speicher, Android 6.0) grau',
#                8.0632)],
#              'alendika': [('Huawei P8 Lite - Smartphone de 5" (cámara 13 MP, 16 GB, HiSilicon Kirin 620 Octa Core 1.2 GHz, 2 GB RAM, Android L), color negro',
#                8.0632)],
#              'Вадим': [('Huawei G610-C00', 8.0632),
#               ('Samsung Galaxy S4 GT-I9500 16GB (черный)', 8.0632)],
#              'SuSi': [('Sony Ericsson T610 Handy silber', 8.0632)],
#              'Algerian Amine': [('ZUK Z1 Smartphone 4G 5.5 inch IPS Screen Cyanogen OS 12.1 USB3.0 Type-C Connector Qualcomm Snapdragon 801 2.5GHz Dual Cameras Fingerprint Identification',
#                8.0632)],
#              'BerrySweetie ': [('Samsung Galaxy S III 16GB (Virgin Mobile)',
#                8.0632)],
#              'Potter': [('SAMSUNG Galaxy S4 16 Gb i9505 negro', 8.0632)],
#              'Pau Jovell': [('Meizu M3S - Smartphone libre Android (5", 16 GB, 2 GB de RAM, 13 MP), color gris',
#                8.0632)],
#              'Sabine Morkisch': [('Samsung SGH-G600 5 Megapixel Handy',
#                8.0632)],
#              'B. Roberts': [('Motorola Moto G LTE- Factory Unlocked US Warranty (Black)',
#                8.0632)],
#              'Влад': [('Acer Liquid E2 Duo V370 Classic White', 8.0632)],
#              'Игорь': [('Apple iPhone 5s 16GB (серебристый)', 10)],
#              'prozzac': [('Nokia Lumia 710', 8.0632)],
#              'Gianfranco Bussani': [('Huawei P8 Lite Smartphone, Display 5" IPS, Processore Octa-Core 1.5 GHz, Memoria Interna da 16 GB, 2 GB RAM, Fotocamera 13 MP, monoSIM, Android 5.0, Bianco [Italia]',
#                8.0632)],
#              'ramazan': [('Nokia (438) C5', 8.0632)],
#              'abd2o': [('Ecouteur Casque Oreillette cable Blanc Origine SAMSUNG Control Volume GT-i9505 / GT-i9500 Galaxy S4',
#                8.0632)],
#              'Rudy Martens': [('Huawei P8 Lite Goud', 8.0632)],
#              'Peter': [('Nokia Lumia 630 UK SIM-Free Smartphone - Orange (Windows, 4.5-inch, 8GB)',
#                8.0632)],
#              'Sellar': [('Nokia 6230i', 8.0632)],
#              'Beate Schreiber': [('Samsung Wave II S8530 Smartphone (9,5 cm (3,7 Zoll) Display, Super Clear LCD Touchscreen, 5 Megapixel Kamera) ebony-gray',
#                8.0632)],
#              'Meck Sunday': [('Samsung Galaxy Ace S5830 Smartphone (8,9 cm (3,5 Zoll) Display, Touchscreen, Android OS, 5 Megapixel Kamera) weiß',
#                8.0632)],
#              'Luigi': [("Alcatel Idol 4 Smartphone, Display 5.2' Pollici, 16 GB Memoria interna, 3GB RAM, Fotocamera 13MP, Dual SIM, Android 6.0 Marshmallow, VR incluso, Grigio [Italia]",
#                8.0632)],
#              'twi14': [('Sony Ericsson W705', 8.0632)],
#              'dolunay': [('Blackberry 7290 Series', 8.0632)],
#              'katyasa13': [('Nokia C6-00', 8.0632)],
#              'A Faisal': [('EE Pay As You Go Nokia 130 Mobile Phone - Black (Includes GBP10 Pre Loaded Credit, Unlimited Texts, 150 Minutes, 500 MB Data)',
#                8.0632)],
#              'mr.zomtec': [('Samsung SGH-E250', 8.0632)],
#              'Мамеднабиев Ахмед': [('Samsung Galaxy S5 SM-G900F 16Gb',
#                8.0632)],
#              'Anita1987': [('Samsung Galaxy S6 zwart / 32 GB', 8.0632)],
#              'hawwa': [('Samsung M310 Cep Telefonu', 8.0632)],
#              'cemil': [('HTC (187) 7 Pro', 8.0632)],
#              'OBEONECANOBI "JEORGE"': [('Pantech Laser P9050 Unlocked GSM Phone with AMOLED Touchscreen, Slide-out QWERTY Keyboard, 3.15MP Camera, Video...',
#                8.0632)],
#              'Phil': [('LG CU920 QuadBand Unlocked Phone with Touch Screen, MP3 Player and 2MP Camera - US Warranty - Black',
#                8.0632)],
#              'Gabrielle Mellen': [('Sprint LG Volt White (Sprint Prepaid)',
#                8.0632)],
#              'Isabel': [('Samsung B2100 Unlocked Quad-Band Phone, Extreme Anti-Shock, Waterproof, Built-in Flashlight, Bluetooth-International Version-Black',
#                8.0632)],
#              'l-ananin': [('Nokia 6233', 8.0632)],
#              'mrpaella': [('Nokia 3210E', 8.0632)],
#              'Andrea': [('Lenovo Motorola Moto G 4G (2 Generazione) Smartphone, Display 5 Pollici, LTE, Fotocamera 8 MP, Memoria 8 GB, Android 5 Lollipop, Nero [Italia]',
#                10),
#               ('DOOGEE X5 Pro -- 4G Smartphone 5.0" IPS Android 5.1 Lollipop MT6735 Quad Core 1.0GHz Cellulare Dual SIM 2GB RAM 16GB ROM DG Xender intelligente Wake Air Gesti GPS WIFI (Nero)',
#                8.0632),
#               ('Microsoft Nokia Lumia 730 Smartphone (4,7 Zoll (11,9 cm) Touch-Display, 8 GB Speicher, Windows 8.1) weiß',
#                8.0632),
#               ('Huawei ascendere P7 mini Smartphone (11,4 cm Touchscreen, 1,2 gHz, quadrilatero-nucleo-processore, 1 GB RAM, 8 GB memoria, 8 Megapixel-macchina fotografica con autofocus, androide 4,3)',
#                8.0632)],
#              'Nev': [('Sim Free Sony E5 Mobile Phone', 8.0632)],
#              'susana': [('Cubot X17 S - 4G LTE Smartphone（5.0" FHD 1080*1920pixel MTK6735 64Bit Quad-Core 1.3GHz Android 5.1 16.0MP 3GB RAM 16GB ROM Dual Tarjeta Marco Metálico OTG FM GPS HotKnot)',
#                8.0632)],
#              'Martin': [('Microsoft Nokia 6300i all grey (EDGE, Kamera mit 2 MP, Musik-Player, Organizer, WLAN) Handy',
#                8.0632)],
#              'Vinit S.': [('HTC One E8 (White)', 8.0632)],
#              'MiniS': [('HTC One', 8.0632)],
#              'vedelorme': [('myTouch 4G', 8.0632)],
#              'Кошелев Егор': [('Samsung Star GT-S5230', 8.0632)],
#              'budi': [('Blackberry 8700g Series', 8.0632)],
#              'Донской Леонид': [('Meizu MX3 16Gb', 8.0632)],
#              'happygurlsunshine': [('Samsung T404G Prepaid Phone (Net10)',
#                8.0632)],
#              'Abhi': [('Sim Free Samsung Galaxy S7 Mobile Phone - Black',
#                8.0632)],
#              'Yaari': [('טלפון סלולרי Sony Xperia Z5 Premium', 8.0632)],
#              'alessio': [('WIKO Fever 4G Smartphone, 16 GB, Dual SIM, Nero/Antracite',
#                8.0632)],
#              'Selina': [('Samsung Galaxy Y S5360 Smartphone (7,62 cm (3 Zoll) Display, Touchscreen, 2 Megapixel Kamera, Android 2.3) pure-white',
#                8.0632)],
#              'Raúl SD': [('Nokia 225 - Teléfono móvil (7,11 cm (2.8"), 240 x 320 Pixeles, LCD, MicroSD (TransFlash), 32 GB, 2 MP) Negro',
#                8.0632)],
#              'sasafarkas': [('Huawei Honor 8 32GB', 8.0632)],
#              'silverfang77': [('Samsung SPH-A660', 8.0632)],
#              'Tulsinath': [('Sony Ericsson C510', 8.0632)],
#              'c.ledenyowa': [('Nokia 6303 Classic', 8.0632)],
#              'Mimi Taylor': [('OnePlus 3 A3000 64GB Graphite, 5.5", Dual Sim, GSM Unlocked International Model, No Warranty',
#                8.0632)],
#              'vano': [('Nokia 6700 classic', 8.0632)],
#              'Смолев Виталий': [('Lenovo A516', 8.0632)],
#              'GLRM GLRM': [('Huawei Ascend Y210D', 8.0632)],
#              'DyingJedi': [('Samsung Galaxy Alpha G850a Unlocked Cellphone, 32GB, Dazzling White',
#                8.0632)],
#              'Robbie': [('Sim Free Motorola Moto G 4th Generation Mobile Phone - Black',
#                8.0632)],
#              'Silvana Maria Gomes Ribeiro': [('Smartphone Samsung Galaxy S5 Duos G900MD Desbloqueado Branco',
#                8.0632)],
#              'B.H.': [('Samsung SGH-D900i silber Handy', 8.0632)],
#              'Pranay Agarwal': [('Motorola Moto G Turbo (White, 16GB)',
#                8.0632)],
#              'hplter': [('Sony Xperia go', 8.0632)],
#              'ama.ric': [('Nokia E52 (black) sim-free, unbranded, no contract',
#                8.0632)],
#              'Bernhard Teufel': [('Lenovo Moto G4 Smartphone (14 cm (5,5 Zoll), 16GB, Android) weiß',
#                8.0632)],
#              'akkshay': [('Lenovo Used Lenovo Zuk Z1 (Space Grey, 64GB)',
#                8.0632)],
#              'Michael Schade': [('Microsoft Nokia 108 Dual-SIM Handy (4,5 cm (1,8 Zoll) Farbdisplay, 0,3 Megapixel Kamera, UKW-Radio, Bluetooth) rot',
#                8.0632)],
#              'Marilyn': [('Apple iPhone 5 A1428 Factory Unlocked Cellphone, 16GB, Black',
#                8.0632)],
#              'Alexander': [('LG Electronics G2 mini Smartphone (4,7 Zoll (11,9 cm) Touch-Display, 8 GB Speicher, Android 4.4) rot',
#                8.0632)],
#              'Xando': [('Samsung Galaxy S6 edge zwart / 32 GB', 8.0632)],
#              'antonio spagnuolo': [('Microsoft Lumia 640 XL LTE Smartphone, 8 GB, Nero [Italia]',
#                8.0632)],
#              'mefody.ambalov': [('Nokia 2700 Classic', 8.0632)],
#              'jordi46': [('Meizu M2 Note - Smartphone libre Flyme (pantalla de 5.5", cámara de 13 Mp, 16 GB, Octa-Core de 1.3 GHz, 2 GB RAM), gris',
#                8.0632)],
#              'Hgray97': [('LG None None', 8.0632)],
#              'satinderjeet': [('Samsung Galaxy Note 5', 8.0632)],
#              'Dario Pietro Cavallo': [('Lenovo Motorola Moto G Smartphone, 4,5 pollici display HD, processore Qualcomm, memoria 16GB, MicroSIM, Android 4.3 OS, fotocamera da 5 MP, Nero [Germania]',
#                8.0632)],
#              'dibil krishna': [('Lenovo A680 (Black)', 8.0632)],
#              'FER_CENIZA': [('Blackberry 9700 Bold2', 8.0632)],
#              'Корлюга Юлия': [('Alcatel OneTouch IDOL Ultra 6033', 8.0632)],
#              'S.A.': [('Apple iPhone 6 128GB 4G LTE Factory Unlocked GSM Smartphone - Space Gray',
#                8.0632)],
#              'Cindy L': [("Huawei P9 lite Smartphone débloqué 4G [Version Europe de l'Ouest] or",
#                8.0632)],
#              'michael rowe': [('LG Nitro HD LG-P930 AT&T 4G LTE Unlocked Cell Phone No Warranty - AT&T Logos [AT',
#                8.0632)],
#              'Pedro Herrera': [('NEW Lg Optimus G Pro Black 16gb E988 5.5" 13mp 3g 4g LTE ; Factory Unlocked - International Version No Warranty',
#                8.0632)],
#              'recreatiejob': [('Samsung Galaxy S6 edge zwart / 32 GB',
#                8.0632)],
#              'Shelley_13': [('Nokia 6260', 8.0632)],
#              'Katjuusa78': [('Samsung Galaxy S6 32 Gt Android puhelin, valkoinen',
#                8.0632)],
#              'Manfredi': [('Sony Xperia Z3 Compact Smartphone, 16 GB, Nero [Italia]-Nano Sim',
#                8.0632)],
#              'sarah lacey': [('Apple iPhone 5 16GB (White) - Sprint (does not include sim card)',
#                8.0632)],
#              'Azef': [('Смартфон HTC Desire 310 DS 4.5" 4Gb White', 8.0632)],
#              'tlt83': [('Sony Ericsson K750i', 8.0632)],
#              'Dr Arm': [('Kyocera Oystr KX9d', 8.0632)],
#              'Ahaar': [('Sony Xperia E Dual-SIM Smartphone (8,9 cm (3,5 Zoll) Touchscreen, Qualcomm, 1GHz, 512MB RAM, 4GB HDD, 3,2 Megapixel Kamera, Android 4.0) gold',
#                8.0632)],
#              'axy': [('Moto G 8GB', 8.0632)],
#              'SAMUELCELSO': [('Nokia E72', 8.0632)],
#              'Wittwer': [('Samsung Galaxy Note Edge Smartphone (5,6 Zoll (14,2 cm) Touch-Display, 32 GB Speicher, Android 4.4) charcoal black',
#                8.0632)],
#              'Julien': [('Samsung Galaxy Xcover2 Smartphone d??bloqu?? 3G Bluetooth Wi-Fi Android 4 Go Gris (import Europe)',
#                8.0632)],
#              'Sammuel': [('??????????????? HTC Desire SV', 8.0632)],
#              'Jean-Marie Descamps': [('Kit Me Out FR Coque en gel TPU pour Nokia Lumia 625 - noir impression givre',
#                8.0632)],
#              'zloy.moroz': [('Sony Ericsson Xperia arc', 8.0632)],
#              'MandieB ': [('Samsung Galaxy S7 32GB (T-Mobile)', 8.0632)],
#              'europetr4': [('Nokia Lumia 625', 8.0632)],
#              'Александр': [('Samsung Смартфон Samsung Galaxy J mini SM-J105H/DS Black',
#                8.0632),
#               ('Sony Xperia ZR (белый)', 8.0632),
#               ('Мобильный телефон Samsung J105H/DS Galaxy J1 Mini Duos White (SM-J105HZWDSEK)',
#                8.0632)],
#              'Dhruv Patar': [('Samsung Galaxy J2 6 4G DUOS SM-J210FZDDINS (Gold, 8GB)',
#                8.0632)],
#              'Oliver Fink': [('Nokia 100 Festival Pink (4,6 cm (1,8 Zoll) Display, Radio) deutsche Version',
#                8.0632)],
#              'Kmcginn64 ': [('Samsung Galaxy S7 32GB (Verizon)', 8.0632)],
#              'dilemma21': [('Sony Ericsson W910i Cep Telefonu', 8.0632),
#               ('Samsung J700 1GB Cep Telefonu', 8.0632),
#               ('Samsung U600 Cep Telefonu', 8.0632)],
#              'sunda': [('HTC Incredible S', 8.0632)],
#              'JuppeP': [('Lenovo Ideapad 510 15,6" ‐kannettava, Win 10 64-bit, hopea',
#                8.0632)],
#              'K.Das': [('Lenovo A7000 (Black)', 8.0632)],
#              'Sammy5': [('Curve 8320', 8.0632)],
#              'Esquizolol': [('Samsung Galaxy S6 Edge - Smartphone libre Android (pantalla 5.1", cámara 16 Mp, 32 GB, Quad-Core 2.1 GHz, 3 GB RAM), dorado (importado de Italia)',
#                8.0632)],
#              'pulkit sethi': [('OnePlus 3 (Soft Gold, 64 GB)', 8.0632)],
#              'cristian': [('Meizu M3 Note - Smartphone libre Android (5.5", 13 MP, 2 GB RAM, 16 GB, 4G), color negro',
#                8.0632)],
#              'rudgero': [('Smartphone LG G Flex', 8.0632)],
#              'N. Talevski': [('Microsoft Nokia 6300 white (EDGE, GPRS, Kamera mit 2 MP, Musik-Player, Bluetooth, Organizer) Handy',
#                8.0632)],
#              'Joseph Corrao': [('Pantech Hotshot CDM8992 Verizon CDMA Phone with Touchscreen, 3.15MP Camera, Video, GPS, Bluetooth, MP3/MP4 Player and microSD Slot - Red',
#                8.0632)],
#              'P.D. Prins': [('HTC Wildfire S', 8.0632)],
#              'miatamania': [('Nokia N76 Cep Telefonu', 9.0)],
#              'Darren': [('Sony Xperia Z UK SIM-Free Smartphone - Purple',
#                8.0632)],
#              'Manamana78': [('LG Electronics KP100 Handy schwarz', 8.0632)],
#              'J.T.': [('Samsung Galaxy Gio (S5660) Smartphone (8,13 cm (3,2 Zoll) Touchscreen, 3 Megapixel Kamera, Android 2.3.3) silber',
#                8.0632)],
#              'Olga': [('LG P715 Optimus L7 II Dual (Black)', 8.0632)],
#              'Lylas-Tipps': [('Nokia Lumia 730 Dual SIM', 8.0632)],
#              '??????????????? ????????????????': [('?????????????? ?????????????? HTC Desire C Red',
#                8.0632)],
#              'Rafael Barichello Oliveira': [('Smartphone Samsung Galaxy A5 2016 Duos A510 Desbloqueado Dourado',
#                8.0632),
#               ('Smartphone Samsung Galaxy A5 2016 Duos A510 Desbloqueado Rosa',
#                8.0632)],
#              'Amazon-Kunde': [('HTC One Mini Smartphone (10,9 cm (4,3 Zoll) LCD-Display, 1,4GHz, Dual-Core, 1GB RAM, Ultrapixel Kamera, Android 4.2) hellblau',
#                10)],
#              'gambitt': [('7230 / 7210', 8.0632)],
#              'Inma': [('HOMTOM HT7 - Smartphone Libre Android 5.1 (Quad Core, Pantalla 5.5", IPS 1280*720 HD, 1GB RAM, 8GB ROM, Cámara 5.0MP, Dual SIM, Smart Wake) Blanco',
#                8.0632)],
#              'sisi': [('Microsoft Nokia 5310 XpressMusic blue (EDGE, Musik-Player, UKW-Radio, Kamera mit 2 MP, Bluetooth) Triband Handy',
#                8.0632)],
#              'e-bit': [('Smartphone Motorola Moto G 4 XT1626', 10),
#               ('Smartphone LG G3 D855', 9.465793172690763),
#               ('Smartphone Samsung Galaxy Gran Prime TV SM-G530', 9.32),
#               ('Smartphone Samsung Galaxy J7 SM-J700M', 9.32),
#               ('Smartphone Samsung Galaxy S5 SM-G900', 8.64)],
#              'Harry "Harry"': [('Samsung SGH-E250i Handy silver', 8.0632)],
#              'kyef': [('LG KG920 Cep Telefonu', 8.0632),
#               ('LG KF240 Cep Telefonu', 8.0632),
#               ('LG KU 380 Cep Telefonu', 8.0632),
#               ('LG KG 270 Cep Telefonu', 8.0632)],
#              'Moe': [('Samsung Galaxy J7 Prime (32GB) G610F/DS - 5.5" Dual SIM Unlocked Phone with Finger Print Sensor (White Gold)',
#                8.0632)],
# ...
#                8.0632)],
#              'Roxanelle': [('Apple iPhone 6s 32 GB', 8.0632)],
#              'Zach': [('HTC G1 Google Android Unlocked Phone with Android OS, Wi-Fi, Bluetooth, 3MP Camera, MicroSD Expansion - Unlocked Phone - US Warranty - Black',
#                8.0632)],
#              'Gérard': [('Nokia LUMIA520W Smartphone débloqué Windows Phone Bluetooth Blanc',
#                8.0632)],
#              'Baybish ': [('Samsung Galaxy S5 16GB (Verizon)', 8.0632)],
#              'Kosumi61 ': [('Samsung Galaxy J5 ‐Android-puhelin, musta',
#                8.0632)],
#              'Equilibrium': [('Samsung Galaxy S4', 8.0632)],
#              'Vishal Meena': [('Motorola Moto E 2nd Generation (3G, White)',
#                8.0632)],
#              'smcb66': [('Vu / CU920 / CU915', 8.0632)],
#              'Aman Modi': [('Lenovo Used Lenovo Zuk Z1 (Space Grey, 64GB)',
#                8.0632)],
#              'Kamui': [('Smartphone LG G2 Branco com Tela de 5.2”, Android 4.2, Câmera 13MP, 3G/4G e Processador Snapdragon 800 Quad Core de 2.26GHz',
#                8.0632)],
#              'pavelporusski2012': [('LG Optimus L9 P765', 8.0632)],
#              'Oleksandr Prokopenko': [('Samsung N910H Galaxy Note 4 (Charcoal Black)',
#                8.0632)],
#              'Hasan': [('iPhone 3G', 8.0632)],
#              'ivan velasquez': [('Sony Ericsson Xperia S LT26i Unlocked Android 32gb Wifi Enabled 3g Phone, Black',
#                8.0632)],
#              'Susana González Alegre': [('Samsung Galaxy S III mini (I8190) - Smartphone libre Android (pantalla 4", cámara 5 Mp, 8 GB, Dual-Core 1 GHz, 1 GB RAM), blanco [importado]',
#                8.0632)],
#              'Prashanthi': [('Asus Zenfone Max ZC550KL-6A068IN (Black, 2GB, 16GB)',
#                8.0632)],
#              'CLEITON BISNAGA': [('LG GX200', 8.0632)],
#              'Narayani': [('Micromax Canvas Fire 4 A107 (Cosmic Grey, 8GB)',
#                8.0632)],
#              'Ricardo R.': [('BLU Studio M HD - 5.0" Smartphone -Global GSM Unlocked -White',
#                8.0632)],
#              'Rosaria': [("ZTE Axon 7 Smartphone 4G LTE, Display 5.5'' IPS 2K 2560*1440 WQHD Fingerprint Touch ID, Android 6.0, Snapdragon 820 Quad Core 2.15GHz, 4GB RAM, 64GB ROM, Dual SIM, Batteria 3250mAh, Oro",
#                8.0632)],
#              'Dimple Garg': [('Nokia Lumia 620 - White', 8.0632)],
#              'E. Alonso "ErlyD"': [('HTC One M8 - Factory Unlocked 32GB - US Warranty (Glacial Silver)',
#                8.0632)],
#              'lamonce V.': [('Samsung Smartphone Samsung Galaxy J7 16 Go Blanc',
#                8.0632)],
#              'cee jay': [('Huawei P8 lite Unlocked Android 4G LTE Smartphone, Octa Core (Black)',
#                8.0632)],
#              'scottsleight94': [('Orange Rio', 8.0632)],
#              'Michael': [('Samsung Galaxy J5 J500M 8GB Unlocked GSM 4G LTE Quad-Core Android Smartphone w/ 13MP Camera - White (International Version)',
#                8.0632),
#               ('iPhone 5S APPLE IPHONE 5S 32GB SILVER UNLOCKED',
#                7.666666666666667)],
#              'tony': [('Samsung Galaxy S5 / S4 / S4 Mini / S3 / Note 2 / Note 3 Original OEM Micro USB 2.0 Charging Data Cable 5ft. - White',
#                10)],
#              'A. C. Yelmo': [('Motorola RAZR Sim-Free Smartphone - Black',
#                8.0632)],
#              'Торубарова Ольга': [('Huawei Ascend Mate', 8.0632)],
#              'Marc': [('APPLE iPhone 6 64 Go argent', 8.0632)],
#              'driedape': [('HTC Legend', 8.0632)],
#              'Вурдалак': [('Nokia 6630', 8.0632)],
#              'allosio': [('Samsung Galaxy S4 Smartphone débloqué 4G (Ecran: 4.99 pouces - 16 Go - Android 4.2 Jelly Bean) Noir (Import Allemagne)',
#                8.0632)],
#              'Константин': [('Телефон Nokia C2-01 Black', 8.0632),
#               ('Sony Xperia Z1 Compact (белый)', 8.0632)],
#              'salame': [('Nokia 5230 Cep Telefonu', 8.0632),
#               ('Nokia 6500c Cep Telefonu', 8.0632)],
#              'Valdo teles': [('Samsung Smartphone Samsung Galaxy S4 Preto 16GB 4G Desbloqueado Android 4.2 WiFi Câmera de 13MP Tela 5 Full HD',
#                8.0632)],
#              'Anonymous': [('Samsung C3212 Duos', 8.0632),
#               ('SAMSUNG Galaxy Light (T-Mobile) 4G LTE Quad-Core 1.4GHz Cell Phone Bundle with MyCharge Voyage 1000mAh & Hypercel Car Charger',
#                8.0632),
#               ('LG Chocolate 3', 8.0632),
#               ('Nokia E71 110 MB internal dynamic memory Gray Unlocked GSM Bar Phone with Full QWERTY Keyboard 2.36"',
#                8.0632),
#               ('Apple Iphone 4s 16GB White Sim Free', 8.0632)],
#              'sharon': [('Nokia 106 Mobile Phone - Black', 8.0632)],
#              'trideeb abraham': [('Apple iPhone 5s (Space Grey, 16GB)',
#                8.0632)],
#              'eenna': [('Nokia Nokia Lumia 735 - Windows Phone - GSM / UMTS - 4G LTE - 8 GB - 4.7" - ClearBlack - Grau [EU-Version]',
#                8.0632)],
#              'Giorgivs': [('Sony Xperia Z3 Compact Smartphone, 16 GB, Nero [Italia]-Nano Sim',
#                8.0632)],
#              'neya94': [('Sony Ericsson K550i', 8.0632)],
#              'alexus911': [('Nokia C3 Touch and Type', 8.0632)],
#              'tolstoy': [('HTC Desire', 8.0632)],
#              'Андрей': [('Sony Xperia Z1 (белый)', 8.333333333333334),
#               ('ASUS Смартфон ASUS ZenFone Max ZF3 ZC520TL 16Gb, серый',
#                8.0632)],
#              'Julian M.': [('Samsung Galaxy S4 mini Smartphone (10,9 cm (4,3 Zoll) Touch-Display, 8 GB Speicher, Android 4.2) schwarz',
#                8.0632)],
#              'Mayara Negry': [('Smartphone Samsung Galaxy S Duos 2 S7582 Desbloqueado Branco',
#                8.0632)],
#              'Christoph Huebner': [('Sony Ericsson M600i granite black Handy',
#                8.0632)],
#              'Mukul Jamloki': [('Motorola Moto G 3rd Generation (Black, 16GB)',
#                8.0632)],
#              'MelP': [('Apple iPhone 4S AT&T Cellphone, 16GB, Black', 8.0632)],
#              'ROSELAYANNE': [('Samsung T459', 8.0632)],
#              'Miggy': [('Lumia Nokia Lumia 625 SIM-Free Smartphone - Black',
#                8.0632)],
#              'MELINA ALGABA GONZÁLEZ': [('Doogee X5 - Smartphone Libre 3G Android 5.1 (Quad Core, 5.0" IPS 1280*720 HD, 1GB RAM, 8GB ROM, 5.0MP Cámara, Dual SIM, GPS, OTG) Celular, color Negro',
#                8.0632)],
#              'Goldi chaudhary': [('OnePlus 2 (Sandstone Black, 16GB)',
#                8.0632)],
#              'Ruchi': [('Lenovo Vibe K5 (Gold, VoLTE update)', 8.0632)],
#              'DIVYADAN TIWARI': [('Panasonic P81 (Black)', 8.0632)],
#              'Jaroslaw Zaczek': [('LG G Flex2 - 16GB - Platina Silver',
#                8.0632)],
#              'Sheila': [('Samsung Galaxy Note 2 Replacement Stylus Pen (Black) (Discontinued by Manufacturer)',
#                10)],
#              'INTEL_WARE': [('Nokia 3300', 8.0632)],
#              'Digital Camera Guy': [('LG 505C Prepaid Phone With Triple Minutes (Tracfone)',
#                8.0632)],
#              'Powermanager': [('Samsung Wave S8500 Smartphone (Super Amoled Display, Touchscreen, bada-Betriebssystem) metallic-black',
#                8.0632)],
#              'Michael Löbbecke': [('Microsoft Nokia 6303i classic Handy (Kamera mit 3,2 MP, MP3, Bluetooth) black',
#                8.0632)],
#              'nupilot ': [('Samsung Galaxy S7 32GB (T-Mobile)', 8.0632)],
#              'bouquet13': [('Sony Ericsson Z750i', 8.0632)],
#              'Boris': [('Samsung Galaxy Core (i8260) - Smartphone libre Android (pantalla 4.3", cámara 5 Mp, 8 GB, 1.2 GHz), Azul [versión europea]',
#                8.0632)],
#              'monteua': [('Nokia 2700 classic', 8.0632)],
#              'pressplay': [('Sony Ericsson W910i', 8.0632)],
#              'Atin Agarwal': [('Nokia Lumia 620 - White', 8.0632)],
#              'Mr U': [('LG G4 Unlocked Smartphone with 32GB Internal Memory, 16 MP Camera and 5.5-Inch IPS Quantum Display for GSM and CDMA, US Warranty (Black Leather)',
#                8.0632)],
#              'bond,james': [('Nokia 3210', 8.0632)],
#              '123deins': [('NOKIA 5800, Nokia X6, N97 mini XpressMusic Display Set',
#                8.0632)],
#              'Helen S.': [('Samsung Galaxy S7 edge Smartphone, 13,9 cm (5,5 Zoll) Display, LTE (4G)',
#                8.0632)],
#              'sprint': [('ZTE V880E Dual SIM', 8.0632)],
#              'crossmax': [('Samsung SGH-M300', 8.0632)],
#              'Vanda Kwok': [('Motorola Moto E (2nd Generation) - White - 8 GB - Global GSM Unlocked Phone',
#                8.0632)],
#              'Cashido ': [('Samsung Galaxy S6 edge+ 64GB (Verizon)', 8.0632)],
#              'sanderson': [('Nokia 7380', 8.0632)],
#              'Belel': [('Nokia 100 - Móvil libre (pantalla de 1,8" 128 x 160), negro',
#                8.0632)],
#              'alvo777': [('HTC Touch HD', 8.0632)],
#              'ALIF': [('Samsung SGH E770', 8.0632)],
#              'Kirby Rose Hunter': [('Motorola Moto G Smartphone - 8GB - For Verizon Pre-Paid',
#                8.0632)],
#              'martina catalano': [('LG D722 G3 S Smartphone, 8 GB, Nero Metallico [Italia]',
#                8.0632)],
#              'Vrs': [('OnePlus 3T (Gunmetal, 6GB RAM + 64GB memory)', 8.0632)],
#              'Martina': [('WIKO Rainbow Smartphone, 4G, 8 GB, Nero', 8.0632)],
#              'elizabeth': [('Sprint LG Volt White (Sprint Prepaid)', 8.0632)],
#              'Shriya Arora': [('Apple iPhone 5s (Silver, 16GB)', 8.0632)],
#              'fullthrottle1974': [('BlackBerry Pearl 3G 9100', 8.0632)],
#              'BigTycoon': [('Nokia 5110', 8.0632)],
#              'john filliter': [('Samsung E1200i Keystone 2 Mobile Phone (EE Pay as you go, Black)',
#                8.0632)],
#              'DBFRANCE': [('ZTE Blade S6 Plus 4G LTE Téléphone portable 5.5 pouces écran IPS HD 1280*720 Octa-core Qualcomm MSM8939 2Go + 16Go 5.0 Android L Caméras 13.0 MP & 5.0 MP Supporte Double SIM pour Orange SFR Bouygues Free',
#                8.0632)],
#              'Heinz Gieger': [('Wiko Rainbow Smartphone (12,7 cm (5 Zoll) Display 4 GB interner Speicher, Android 4.2) pink',
#                8.0632)],
#              'Rinku Dey': [('Lenovo Vibe K4 Note (Black, 16GB)', 8.0632)],
#              'ajeet singh': [('OnePlus 3 (Soft Gold, 64 GB)', 8.0632)],
#              'nicbv': [('LG A275 Black Unlocked GSM Dual SIM QuadBand Cell Phone - International Version - No Warranty',
#                8.0632)],
#              'Федор': [('LG X power (золотистый)', 8.0632)],
#              'Steffen Mayle': [('Blackberry Z10 Smartphone (4,2 Zoll Display, Touchscreen, 8 Megapixel Kamera, 16 GB erweiterbarer Speicher, 4G LTE) schwarz',
#                8.0632)],
#              'casper-2007': [('Samsung Galaxy S Duos GT-S7562', 8.0632)],
#              'michaeljones': [('Microsoft Nokia Lumia 630 UK SIM-Free Smartphone - Black (Windows, 4.5-inch, 8GB)',
#                8.0632)],
#              'Francesco Uchiha': [('Samsung G935 Galaxy S7 Edge Smartphone da 32GB, Argento [Italia]',
#                8.0632)],
#              'Газеев Артур': [('Sony Ericsson Live with Walkman', 8.0632)],
#              'NicoCel': [('Huawei P8 lite Unlocked Android 4G LTE Smartphone, Octa Core (Black)',
#                8.0632)],
#              'Jimwest': [('Leathlux Protection écran Zenfone 3 ZE520KL, Leathlux [0.26mm] Ultra Clair Verre Trempé Protecteur D\'écran Dureté 9H HD Clarté Vitre Tempered Film pour Asus Zenfone 3 ZE520KL 5.2"',
#                8.0632)],
#              'Juliette': [('APPLE iPhone 7 - Silver, 128 GB', 8.0632)],
#              'F. M.': [('HTC One (M8) Smartphone (12,7 cm (5 Zoll) LCD-Display, Quad-Core, 2,3GHz, 2GB RAM, 5 Megapixel Frontkamera, FM-Radio, Android 4.4.2) metallgrau - [T-Mobile-Branding]',
#                8.0632)],
#              'Heiko': [('Nokia 2680 slide slate gray (GPRS, VGA-Kamera, UKW-Stereo-Radio, Bluetooth, Organizer) Handy',
#                8.0632)],
#              'gemini85': [('Motorola M3788', 8.0632)],
#              'Pogyz "Pogyz"': [('Nokia 7230 Téléphone portable GSM/GPRS/EDGE Bluetooth Graphite',
#                8.0632)],
#              'Jenelle': [('Motorola Droid 3 Verizon Xt862 Verizon Cell Phone',
#                8.0632)],
#              'lupamajor': [('Palm Treo 600', 8.0632)],
#              'Kexs': [('Samsung Galaxy S6 64 GB UK SIM-Free Smartphone - Gold',
#                8.0632)],
#              'VERZY LYDIE': [('Samsung GT-B2710 Téléphone Portable Noir',
#                8.0632)],
#              'Entrup': [('Samsung Wave S8500 Smartphone (Super Amoled Display, Touchscreen, bada-Betriebssystem) metallic-black',
#                8.0632)],
#              'Valmaggia Charles': [('Acer Liquid Jade S Smartphone débloqué 4G (Ecran : 5 pouces - 16 Go - Double SIM - Android 4.4 KitKat) Blanc',
#                8.0632)],
#              'zeynep34': [('Nokia 6288 Cep Telefonu', 8.0632)],
#              'Ndeye-hanan Oltra Abad': [('Nokia X3', 8.0632)],
#              'Ryan': [('Huawei Honor 8 (Sunrise Gold)', 5.333333333333333)],
#              'Emanuele': [('Lenovo Motorola Moto G Smartphone, Display HD 4,5", Processore Qualcomm, Memoria 8 GB, MicroSIM, Android 4.4 OS, Fotocamera da 5 MP, Nero [Germania]',
#                8.0632)],
#              'Linus': [('DOOGEE VALENCIA2 Y100 Pro 5.0 Pollici HD Dello Schermo 4G LTE Smartphone Quad Core 13.0MP Fotocamera 2 GB RAM 16GB ROM',
#                8.0632)],
#              'Warren M.': [('Samsung Galaxy S7 Edge Dual Sim Factory Unlocked Phone 32 GB - Internationally Sourced (Middle East/Africa/Asia) Version G935FD- Black Oynx',
#                8.0632)],
#              'incesaz': [('Nokia E50 (Metal Black) Cep Telefonu', 8.0632)],
#              'Roseli Aparecida Defassio': [('Smartphone Motorola Novo Moto G DTV Colors, Dual Chip, 3G, 16GB - XT1069',
#                8.0632)],
#              'Chey chey': [('LG G5', 8.0632)],
#              'naman': [('Samsung Guru GT-E1200 (Indigo Blue)', 8.0632)],
#              'Александр Дабл': [('Nokia X2-02', 8.0632)],
#              'Yank1 ': [('Samsung Galaxy S7 32GB (Verizon)', 8.0632)],
#              'Dimitri L.': [('Sony Mobile Xperia ZL C6506 Black 4G LTE Quad-Core 1.5 GHz 16GB Unlocked Cell Phone',
#                8.0632)],
#              'кокорин рома': [('Samsung S5610', 8.0632)],
#              'Praveen': [('Motorola Moto X (2nd generation) Unlocked Cellphone, 16GB, White/Bamboo',
#                8.0632),
#               ('YU Yuphoria YU5010A (Black+Silver)', 8.0632)],
#              'FumieZ': [('Samsung Galaxy SII LTE | Black', 8.0632)],
#              'Constantia': [('Samsung Galaxy S7 Edge zwart / 32 GB', 8.0632)],
#              'Kadir Bayraktar': [('HTC 8X Blauw', 8.0632)],
#              'Gast': [('Asus P535', 8.0632)],
#              'Muyiwa A. Oludiran': [('Samsung Galaxy Core Prime DUAL SIM Simfree 8GB 4.5 Inch Touch Screen Smartphone - Charcoal Grey',
#                8.0632)],
#              'zac6987': [('HTC Wildfire', 8.0632)],
#              'Gabriel Jann': [('LG Electronics Mobile Google Nexus 5 12,6 cm (4,9 Zoll) Smartphone (Touch-Display, 32 GB Speicher, Android 4.4) schwarz',
#                8.0632)],
#              'Максим Когут': [('Nokia 101 Premium Black', 8.0632)],
#              'andy': [('Samsung Galaxy S II i9100 DualCore Smartphone (10,9 cm (4,3 Zoll) Touchscreen Display, Android 4.0 oder höher, 8 MP Full-HD Kamera, 2 MP Frontkamera) ceramic-white',
#                7.0)],
#              'Ricardo': [('Huawei Ascend P6 - Smartphone libre Android (pantalla 4.7 pulgadas, cámara 8 Mp, 8 GB, 1.5 GHz, 1GB RAM), negro',
#                8.0632)],
#              'Jaydee413 ': [('Samsung Galaxy S7 32GB (Verizon)', 8.0632)],
#              'Raoul': [('SAMSUNG Galaxy S6 Edge 128Go noir', 8.0632)],
#              'Vinod chaudhary': [('XOLO Q1000 Opus (White, 4GB)', 8.0632)],
#              'emili9': [('Мобильный телефон Nokia 1100', 8.0632)],
#              'Agusq': [('Sony Xperia Z5 zwart / 32 GB', 8.0632)],
#              'Халилов Айнур': [('Sony Ericsson W960i', 8.0632)],
#              'olgavas89': [('Nokia Lumia 820 Black', 8.0632)],
#              ...})

# %% [markdown]
# ### 9. Try other techniques (Example: cross validation) to get better results. [3 Marks]

# %%
from surprise.model_selection import KFold

kfold = KFold()

recommender = SVD() # using SVD since it works with entire dataset and not just 1% of it

# %%
final_dataset__ = DATA.copy()

final_dataset__.rename(columns = {
                               "score" : "rating",
                               "author" : "userID",
                               "product" : "itemID"
                               }, inplace = True)
final_dataset__.reset_index(inplace = True)
final_dataset__.drop("country", axis = 1, inplace = True)

reader = Reader(rating_scale=(0, 10))

final_final_dataset__ = Dataset.load_from_df(final_dataset__[['userID', 'itemID', 'rating']], reader)
for training_data, testing_data in kfold.split(final_final_dataset__):

    # train and test algorithm.
    recommender.fit(training_data)
    predictions__ = recommender.test(testing_data)

    # Compute and print Root Mean Squared Error
    accuracy.rmse(predictions__)
# Out:
# RMSE: 2.4696
# RMSE: 2.4795
# RMSE: 2.4747
# RMSE: 2.4717
# RMSE: 2.4656

# %% [markdown]
# ### 10. In what business scenario you should use popularity based Recommendation Systems ? [2 Marks]
#
# **Scenarios where we are suffering from the cold start or grey sheep problem are ideal for using popularity based recommendation systems**

# %% [markdown]
# ### 11. In what business scenario you should use CF based Recommendation Systems ? [2 Marks]
#
# **When one has sufficient user data to group similar users together and provide accurate personalized recommendations, CF will be useful**

# %% [markdown]
# ### 12. What other possible methods can you think of which can further improve the recommendation for different users ? [2 Marks]
#
#
# **• There is Context Aware Collaborative Filtering, which can provide even more personalized recommendations, assuming you have the data for it**
#
# **• Hybrid recommendation systems can help combat the lack of data as well as the lack of personalization in recommendations assuming the different recommendation models are mixed properly and their composition is changed appropriately as the amount of data avaialable and the scope of the task increases**
